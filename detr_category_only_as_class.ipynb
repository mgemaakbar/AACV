# %%
from google.colab import drive # the real images data files take too long (about 17 minutes) to be downloaded, so we just mount it
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xzf /content/drive/MyDrive/nuimages/nuimages-v1.0-all-metadata.tgz && tar -xzf /content/drive/MyDrive/nuimages/nuimages-v1.0-all-samples.tgz # extract. this will take about 7 minutes

# %%
drive.flush_and_unmount() # unmount when we don't need it anymore, so we have more disk space

# %%
# !mkdir train2017 val2017 annotations

# %%
import json
import pandas as pd
import datetime

def data_json_to_joined_df(path_prefix_to_json, percent = 100, random_sample=False):
    # percent: take only certain percent of the images
    # random_sample: True if you want to randomize which images to take

    category = pd.read_json(path_prefix_to_json + 'category.json').rename(columns={"name": "category_name"})
    category = category.sort_values(by='category_name')
    category['category_id'] = range(len(category))

    obj_ann = pd.read_json(path_prefix_to_json + 'object_ann.json')
    sample_data = pd.read_json(path_prefix_to_json + 'sample_data.json')
    sample_data = sample_data[sample_data['filename'].str.startswith('sample')] # take only keyframe images (annotated images) which always start with 'samples'. sweeps images are not annotated
    n_rows = int(len(sample_data) * (percent / 100))
    if random_sample:
        sample_data = sample_data.sample(n = n_rows)
    else:
        sample_data = sample_data.iloc[:n_rows]

    # object annotation inner join sample_data
    merged = obj_ann.merge(
        sample_data,
        how = 'inner',
        right_on='token',
        left_on='sample_data_token',
        suffixes=('_left', '_right')
    )

    merged = merged.merge(
        category,
        how = 'left',
        left_on='category_token',
        right_on='token',
        suffixes=('_from_merged', '_from_category')
    )

    return merged

# create list of train/val/test image file name list in a txt file (train/val.txt), so we can use cp/rsync with it
def create_image_filename_list_txt(data_split, merged_df):
    if data_split not in ['train', 'val', 'test']:
        return -1

    df = merged_df[['filename']]
    filenames = set([])
    for index, row in df.iterrows():
        filenames.add(row['filename'])
    for fn in filenames:
        with open(data_split+".txt", 'a') as f:
            f.write(fn + "\n")

def df_to_coco_format(merged_df, path_prefix, split): # DETR uses COCO format
    if split not in ['val', 'train']:
        return -1

    df = merged_df[['filename', 'bbox', 'category_id', 'category_name', 'width', 'height']]

    coco_dict = {"images": [], "annotations": [], "categories": []}
    coco_dict["info"] = { # not including this will cause error during training
        "description": "Nothing",
        "url": "https://github.com/nobody/nothing",
        "version": "2.0.2",
        "year": 2025,
        "contributor": "nobody",
        "date_created": datetime.datetime.utcnow().isoformat(" "),
    }

    is_image_added = {}
    filename_to_id = {}

    id = 0

    # build images
    for i, row in df.iterrows():
        if row['filename'] not in is_image_added: # if image not added yet, then add
            coco_dict["images"].append({
                "id": id,
                "width": row['width'],
                "height": row['height'],
                "file_name": row['filename'].split("/")[-1],
            })
            filename_to_id[row['filename']] = id
            id += 1
            is_image_added[row['filename']] = True

    # build annotations
    for i, row in df.iterrows():
        xmin, ymin, xmax, ymax = row['bbox'][0], row['bbox'][1], row['bbox'][2], row['bbox'][3]
        coco_dict["annotations"].append({
            "id": i,
            "image_id": filename_to_id[row['filename']],
            "category_id": row['category_id'],
            "area": (xmax - xmin) * (ymax - ymin),
            "bbox": [xmin, ymin, xmax - xmin, ymax - ymin], # top left, width, height
            "iscrowd": 0, # not including this will cause an error during training
            "date_captured": datetime.datetime.utcnow().isoformat(" "),
            "license": 0,
            "flickr_url": "",
            "coco_url": ""
        })


    # build category
    category = pd.read_json(path_prefix + 'category.json').rename(columns={"name": "category_name"})
    category = category.sort_values(by='category_name')

    for i, row in category.iterrows():
        coco_dict["categories"].append({
            "id": i,
            "name": row["category_name"],
        })

    with open(split + ".json", "w") as file:
        file.write(json.dumps(coco_dict))

# %%
val_df = data_json_to_joined_df('/content/v1.0-val/',1, random_sample=False)
train_df = data_json_to_joined_df('/content/v1.0-train/',1, random_sample=False)

# %%
create_image_filename_list_txt('train', train_df)
create_image_filename_list_txt('val', val_df)

# %%
# make sure the val.txt exists before running this
# copy the val image to directory expected by yolo. should take about 1 minute for the entire dataset
# !xargs -a val.txt -P8 -I{} cp "/content/{}" /content/val2017/

# %%
# make sure the train.txt exists before running this
# copy the train image to directory expected by yolo. should take about 5 minutes for the entire dataset
# !xargs -a train.txt -P8 -I{} cp "/content/{}" /content/train2017/

# %%
df_to_coco_format(val_df, '/content/v1.0-val/', 'val')
df_to_coco_format(train_df, '/content/v1.0-train/', 'train')

# %%
# !pip install pycocotools
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (2.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools) (2.0.2)

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.6.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import os
import random

ann_file = '/content/train.json'
img_dir = '/content/train2017/'

coco = COCO(ann_file)

imgIds = coco.getImgIds()
img_id = imgIds[random.randint(1, len(imgIds)-1)]
img_info = coco.loadImgs(img_id)[0]
print ("File name: ", img_info['file_name'])
img_path = os.path.join(img_dir, img_info['file_name'])
print ("Image path: ", img_path)

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

ann_ids = coco.getAnnIds(imgIds=img_id)
anns = coco.loadAnns(ann_ids)

dpi = 100
height, width = img.shape[:2]
figsize = (width / dpi, height / dpi)

fig, ax = plt.subplots(1, figsize=figsize, dpi=dpi)
ax.imshow(img)

for ann in anns:
    x, y, w, h = ann['bbox']
    rect = patches.Rectangle((x, y), w, h, linewidth=2,
                             edgecolor='r', facecolor='none')
    ax.add_patch(rect)

ax.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# File name:  n008-2018-05-30-16-31-36-0400__CAM_BACK__1527712507037570.jpg
# Image path:  /content/train2017/n008-2018-05-30-16-31-36-0400__CAM_BACK__1527712507037570.jpg

# %% [markdown]
# # Training
# This part uses the link below as the reference
# https://colab.research.google.com/github/woctezuma/finetune-detr/blob/master/finetune_detr.ipynb#scrollTo=rFmDKP0SavNt which uses Facebook's DETR implementation
#
# Modify this line of code https://github.com/woctezuma/detr/blob/finetune/models/detr.py#L321 with the actual of number class (in this notebook's case, 25)
#
# Read the notebook to find more explanation. Also read this https://gist.github.com/woctezuma/e9f8f9fe1737987351582e9441c46b5d

# %%
# !cp /content/train.json /content/annotations/custom_train.json

# %%
# !cp /content/val.json /content/annotations/custom_val.json

# %%
# %cd /content/

# !rm -rf detr
# !git clone https://github.com/woctezuma/detr.git

# %cd detr/

# !git checkout finetune
# Out:
# /content
# Cloning into 'detr'...
# remote: Enumerating objects: 265, done.
# remote: Total 265 (delta 0), reused 0 (delta 0), pack-reused 265 (from 1)
# Receiving objects: 100% (265/265), 325.44 KiB | 25.03 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# /content/detr
# Already on 'finetune'
# Your branch is up to date with 'origin/finetune'.

# %%
import torch

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

# Save
torch.save(checkpoint,
           'detr-r50_no-class-head.pth')
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth" to /root/.cache/torch/hub/checkpoints/detr-r50-e632da11.pth
# 100%|██████████| 159M/159M [00:07<00:00, 22.0MB/s]

# %%
first_class_index = 0

# %%
def get_classes_list(path_prefix):
  category = pd.read_json(path_prefix + 'category.json').rename(columns={"name": "category_name"})
  category = category.sort_values(by='category_name')
  return category['category_name'].tolist()

finetuned_classes = get_classes_list('/content/v1.0-train/')
num_classes = len(finetuned_classes)
num_classes
# Out:
# 25

# %%
# %cd /content/detr/
# Out:
# /content/detr

# %%
# DETR seems to consume way more GPU RAM than YOLO, use hyperparam like batch size or epoch wisely
# !python main.py \
  --dataset_file "custom" \
  --coco_path "/content/" \
  --output_dir "outputs" \
  --resume "detr-r50_no-class-head.pth" \
  --num_classes $num_classes \
  --epochs 2 \
  --batch_size 4
# Out:
# Not using distributed mode
# git:
#   sha: e891373a8cab93d3719afb0acff28de94c6dc6a3, status: clean, branch: finetune
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=4, weight_decay=0.0001, epochs=2, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, num_classes=25, dataset_file='custom', coco_path='/content/', coco_panoptic_path=None, remove_difficult=False, output_dir='outputs', device='cuda', seed=42, resume='detr-r50_no-class-head.pth', start_epoch=0, eval=False, num_workers=2, world_size=1, dist_url='env://', distributed=False)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 41285406
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Start training
# Epoch: [0]  [  0/149]  eta: 0:06:00  lr: 0.000100  class_error: 100.00  loss: 41.3088 (41.3088)  loss_ce: 3.5443 (3.5443)  loss_bbox: 0.9877 (0.9877)  loss_giou: 2.3532 (2.3532)  loss_ce_0: 3.4468 (3.4468)  loss_bbox_0: 0.9353 (0.9353)  loss_giou_0: 2.3130 (2.3130)  loss_ce_1: 3.5375 (3.5375)  loss_bbox_1: 1.0030 (1.0030)  loss_giou_1: 2.3797 (2.3797)  loss_ce_2: 3.5491 (3.5491)  loss_bbox_2: 1.0195 (1.0195)  loss_giou_2: 2.4149 (2.4149)  loss_ce_3: 3.5613 (3.5613)  loss_bbox_3: 0.9896 (0.9896)  loss_giou_3: 2.3691 (2.3691)  loss_ce_4: 3.5528 (3.5528)  loss_bbox_4: 0.9935 (0.9935)  loss_giou_4: 2.3582 (2.3582)  loss_ce_unscaled: 3.5443 (3.5443)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.1975 (0.1975)  loss_giou_unscaled: 1.1766 (1.1766)  cardinality_error_unscaled: 74.5000 (74.5000)  loss_ce_0_unscaled: 3.4468 (3.4468)  loss_bbox_0_unscaled: 0.1871 (0.1871)  loss_giou_0_unscaled: 1.1565 (1.1565)  cardinality_error_0_unscaled: 78.7500 (78.7500)  loss_ce_1_unscaled: 3.5375 (3.5375)  loss_bbox_1_unscaled: 0.2006 (0.2006)  loss_giou_1_unscaled: 1.1899 (1.1899)  cardinality_error_1_unscaled: 79.7500 (79.7500)  loss_ce_2_unscaled: 3.5491 (3.5491)  loss_bbox_2_unscaled: 0.2039 (0.2039)  loss_giou_2_unscaled: 1.2075 (1.2075)  cardinality_error_2_unscaled: 77.2500 (77.2500)  loss_ce_3_unscaled: 3.5613 (3.5613)  loss_bbox_3_unscaled: 0.1979 (0.1979)  loss_giou_3_unscaled: 1.1846 (1.1846)  cardinality_error_3_unscaled: 75.0000 (75.0000)  loss_ce_4_unscaled: 3.5528 (3.5528)  loss_bbox_4_unscaled: 0.1987 (0.1987)  loss_giou_4_unscaled: 1.1791 (1.1791)  cardinality_error_4_unscaled: 75.0000 (75.0000)  time: 2.4207  data: 0.8623  max mem: 3491
# Epoch: [0]  [ 10/149]  eta: 0:01:56  lr: 0.000100  class_error: 100.00  loss: 25.4922 (26.7889)  loss_ce: 2.8882 (2.9453)  loss_bbox: 0.1651 (0.2610)  loss_giou: 0.9565 (1.0935)  loss_ce_0: 3.2390 (3.2478)  loss_bbox_0: 0.1995 (0.2753)  loss_giou_0: 1.0390 (1.1488)  loss_ce_1: 3.1681 (3.1928)  loss_bbox_1: 0.1753 (0.2697)  loss_giou_1: 0.9870 (1.1189)  loss_ce_2: 3.0640 (3.1056)  loss_bbox_2: 0.1631 (0.2685)  loss_giou_2: 1.0175 (1.1043)  loss_ce_3: 2.9934 (3.0394)  loss_bbox_3: 0.1778 (0.2656)  loss_giou_3: 0.9811 (1.0961)  loss_ce_4: 2.9298 (2.9917)  loss_bbox_4: 0.1695 (0.2626)  loss_giou_4: 0.9697 (1.1019)  loss_ce_unscaled: 2.8882 (2.9453)  class_error_unscaled: 100.0000 (99.8459)  loss_bbox_unscaled: 0.0330 (0.0522)  loss_giou_unscaled: 0.4782 (0.5467)  cardinality_error_unscaled: 63.5000 (52.7273)  loss_ce_0_unscaled: 3.2390 (3.2478)  loss_bbox_0_unscaled: 0.0399 (0.0551)  loss_giou_0_unscaled: 0.5195 (0.5744)  cardinality_error_0_unscaled: 81.7500 (80.4091)  loss_ce_1_unscaled: 3.1681 (3.1928)  loss_bbox_1_unscaled: 0.0351 (0.0539)  loss_giou_1_unscaled: 0.4935 (0.5594)  cardinality_error_1_unscaled: 76.7500 (75.3182)  loss_ce_2_unscaled: 3.0640 (3.1056)  loss_bbox_2_unscaled: 0.0326 (0.0537)  loss_giou_2_unscaled: 0.5087 (0.5522)  cardinality_error_2_unscaled: 74.0000 (67.1818)  loss_ce_3_unscaled: 2.9934 (3.0394)  loss_bbox_3_unscaled: 0.0356 (0.0531)  loss_giou_3_unscaled: 0.4906 (0.5480)  cardinality_error_3_unscaled: 69.5000 (61.5227)  loss_ce_4_unscaled: 2.9298 (2.9917)  loss_bbox_4_unscaled: 0.0339 (0.0525)  loss_giou_4_unscaled: 0.4849 (0.5510)  cardinality_error_4_unscaled: 65.7500 (56.3409)  time: 0.8410  data: 0.0994  max mem: 5401
# Epoch: [0]  [ 20/149]  eta: 0:01:48  lr: 0.000100  class_error: 100.00  loss: 22.4222 (23.6082)  loss_ce: 2.3108 (2.4163)  loss_bbox: 0.2075 (0.2457)  loss_giou: 0.9565 (1.0538)  loss_ce_0: 2.8828 (2.9033)  loss_bbox_0: 0.2063 (0.2605)  loss_giou_0: 1.0185 (1.0969)  loss_ce_1: 2.7432 (2.7761)  loss_bbox_1: 0.1794 (0.2531)  loss_giou_1: 0.9487 (1.0600)  loss_ce_2: 2.5517 (2.6334)  loss_bbox_2: 0.2180 (0.2534)  loss_giou_2: 0.9668 (1.0508)  loss_ce_3: 2.4000 (2.5350)  loss_bbox_3: 0.2065 (0.2465)  loss_giou_3: 0.9511 (1.0454)  loss_ce_4: 2.3303 (2.4730)  loss_bbox_4: 0.2100 (0.2473)  loss_giou_4: 0.9663 (1.0576)  loss_ce_unscaled: 2.3108 (2.4163)  class_error_unscaled: 100.0000 (99.8031)  loss_bbox_unscaled: 0.0415 (0.0491)  loss_giou_unscaled: 0.4782 (0.5269)  cardinality_error_unscaled: 11.5000 (30.5833)  loss_ce_0_unscaled: 2.8828 (2.9033)  loss_bbox_0_unscaled: 0.0413 (0.0521)  loss_giou_0_unscaled: 0.5093 (0.5484)  cardinality_error_0_unscaled: 62.5000 (56.0714)  loss_ce_1_unscaled: 2.7432 (2.7761)  loss_bbox_1_unscaled: 0.0359 (0.0506)  loss_giou_1_unscaled: 0.4743 (0.5300)  cardinality_error_1_unscaled: 49.0000 (45.8571)  loss_ce_2_unscaled: 2.5517 (2.6334)  loss_bbox_2_unscaled: 0.0436 (0.0507)  loss_giou_2_unscaled: 0.4834 (0.5254)  cardinality_error_2_unscaled: 28.0000 (39.1667)  loss_ce_3_unscaled: 2.4000 (2.5350)  loss_bbox_3_unscaled: 0.0413 (0.0493)  loss_giou_3_unscaled: 0.4756 (0.5227)  cardinality_error_3_unscaled: 15.5000 (35.5952)  loss_ce_4_unscaled: 2.3303 (2.4730)  loss_bbox_4_unscaled: 0.0420 (0.0495)  loss_giou_4_unscaled: 0.4831 (0.5288)  cardinality_error_4_unscaled: 11.5000 (32.4167)  time: 0.7627  data: 0.0269  max mem: 6075
# Epoch: [0]  [ 30/149]  eta: 0:01:35  lr: 0.000100  class_error: 100.00  loss: 19.3598 (22.2616)  loss_ce: 1.7884 (2.2382)  loss_bbox: 0.2220 (0.2450)  loss_giou: 1.0134 (1.0316)  loss_ce_0: 2.3091 (2.6983)  loss_bbox_0: 0.2226 (0.2560)  loss_giou_0: 0.9905 (1.0648)  loss_ce_1: 2.1544 (2.5634)  loss_bbox_1: 0.2170 (0.2486)  loss_giou_1: 0.9621 (1.0305)  loss_ce_2: 2.0071 (2.4247)  loss_bbox_2: 0.2220 (0.2487)  loss_giou_2: 0.9970 (1.0304)  loss_ce_3: 1.8738 (2.3366)  loss_bbox_3: 0.2192 (0.2456)  loss_giou_3: 0.9743 (1.0299)  loss_ce_4: 1.8186 (2.2860)  loss_bbox_4: 0.2204 (0.2460)  loss_giou_4: 0.9985 (1.0371)  loss_ce_unscaled: 1.7884 (2.2382)  class_error_unscaled: 100.0000 (99.8666)  loss_bbox_unscaled: 0.0444 (0.0490)  loss_giou_unscaled: 0.5067 (0.5158)  cardinality_error_unscaled: 6.0000 (23.5968)  loss_ce_0_unscaled: 2.3091 (2.6983)  loss_bbox_0_unscaled: 0.0445 (0.0512)  loss_giou_0_unscaled: 0.4953 (0.5324)  cardinality_error_0_unscaled: 7.7500 (40.2823)  loss_ce_1_unscaled: 2.1544 (2.5634)  loss_bbox_1_unscaled: 0.0434 (0.0497)  loss_giou_1_unscaled: 0.4811 (0.5152)  cardinality_error_1_unscaled: 8.0000 (33.7823)  loss_ce_2_unscaled: 2.0071 (2.4247)  loss_bbox_2_unscaled: 0.0444 (0.0497)  loss_giou_2_unscaled: 0.4985 (0.5152)  cardinality_error_2_unscaled: 5.7500 (29.3790)  loss_ce_3_unscaled: 1.8738 (2.3366)  loss_bbox_3_unscaled: 0.0438 (0.0491)  loss_giou_3_unscaled: 0.4872 (0.5150)  cardinality_error_3_unscaled: 6.0000 (26.9758)  loss_ce_4_unscaled: 1.8186 (2.2860)  loss_bbox_4_unscaled: 0.0441 (0.0492)  loss_giou_4_unscaled: 0.4993 (0.5186)  cardinality_error_4_unscaled: 6.0000 (24.8145)  time: 0.7861  data: 0.0277  max mem: 6075
# Epoch: [0]  [ 40/149]  eta: 0:01:29  lr: 0.000100  class_error: 88.89  loss: 18.5114 (21.2555)  loss_ce: 1.6238 (2.0549)  loss_bbox: 0.2083 (0.2563)  loss_giou: 1.0134 (1.0563)  loss_ce_0: 2.0814 (2.5007)  loss_bbox_0: 0.2064 (0.2632)  loss_giou_0: 1.0066 (1.0722)  loss_ce_1: 1.8541 (2.3645)  loss_bbox_1: 0.1921 (0.2532)  loss_giou_1: 1.0059 (1.0460)  loss_ce_2: 1.7374 (2.2300)  loss_bbox_2: 0.1989 (0.2563)  loss_giou_2: 1.0364 (1.0471)  loss_ce_3: 1.6897 (2.1460)  loss_bbox_3: 0.2045 (0.2536)  loss_giou_3: 1.0430 (1.0448)  loss_ce_4: 1.6555 (2.0982)  loss_bbox_4: 0.2094 (0.2557)  loss_giou_4: 1.0392 (1.0564)  loss_ce_unscaled: 1.6238 (2.0549)  class_error_unscaled: 100.0000 (97.4852)  loss_bbox_unscaled: 0.0417 (0.0513)  loss_giou_unscaled: 0.5067 (0.5282)  cardinality_error_unscaled: 6.2500 (19.1037)  loss_ce_0_unscaled: 2.0814 (2.5007)  loss_bbox_0_unscaled: 0.0413 (0.0526)  loss_giou_0_unscaled: 0.5033 (0.5361)  cardinality_error_0_unscaled: 5.7500 (31.7988)  loss_ce_1_unscaled: 1.8541 (2.3645)  loss_bbox_1_unscaled: 0.0384 (0.0506)  loss_giou_1_unscaled: 0.5029 (0.5230)  cardinality_error_1_unscaled: 7.0000 (27.0488)  loss_ce_2_unscaled: 1.7374 (2.2300)  loss_bbox_2_unscaled: 0.0398 (0.0513)  loss_giou_2_unscaled: 0.5182 (0.5235)  cardinality_error_2_unscaled: 6.7500 (23.6951)  loss_ce_3_unscaled: 1.6897 (2.1460)  loss_bbox_3_unscaled: 0.0409 (0.0507)  loss_giou_3_unscaled: 0.5215 (0.5224)  cardinality_error_3_unscaled: 6.0000 (21.7866)  loss_ce_4_unscaled: 1.6555 (2.0982)  loss_bbox_4_unscaled: 0.0419 (0.0511)  loss_giou_4_unscaled: 0.5196 (0.5282)  cardinality_error_4_unscaled: 6.2500 (20.0000)  time: 0.7947  data: 0.0295  max mem: 7215
# Epoch: [0]  [ 50/149]  eta: 0:01:19  lr: 0.000100  class_error: 71.43  loss: 17.1970 (20.4185)  loss_ce: 1.4534 (1.9395)  loss_bbox: 0.2063 (0.2549)  loss_giou: 0.9975 (1.0487)  loss_ce_0: 1.8713 (2.3629)  loss_bbox_0: 0.2064 (0.2614)  loss_giou_0: 1.0114 (1.0662)  loss_ce_1: 1.6998 (2.2274)  loss_bbox_1: 0.1915 (0.2503)  loss_giou_1: 0.9576 (1.0363)  loss_ce_2: 1.5675 (2.0958)  loss_bbox_2: 0.1989 (0.2535)  loss_giou_2: 0.9521 (1.0390)  loss_ce_3: 1.4761 (2.0190)  loss_bbox_3: 0.1930 (0.2500)  loss_giou_3: 0.9351 (1.0361)  loss_ce_4: 1.4560 (1.9771)  loss_bbox_4: 0.1985 (0.2520)  loss_giou_4: 0.9950 (1.0482)  loss_ce_unscaled: 1.4534 (1.9395)  class_error_unscaled: 86.6667 (93.0415)  loss_bbox_unscaled: 0.0413 (0.0510)  loss_giou_unscaled: 0.4988 (0.5243)  cardinality_error_unscaled: 4.7500 (16.4314)  loss_ce_0_unscaled: 1.8713 (2.3629)  loss_bbox_0_unscaled: 0.0413 (0.0523)  loss_giou_0_unscaled: 0.5057 (0.5331)  cardinality_error_0_unscaled: 4.5000 (26.5196)  loss_ce_1_unscaled: 1.6998 (2.2274)  loss_bbox_1_unscaled: 0.0383 (0.0501)  loss_giou_1_unscaled: 0.4788 (0.5182)  cardinality_error_1_unscaled: 6.5000 (23.0245)  loss_ce_2_unscaled: 1.5675 (2.0958)  loss_bbox_2_unscaled: 0.0398 (0.0507)  loss_giou_2_unscaled: 0.4761 (0.5195)  cardinality_error_2_unscaled: 5.0000 (20.0882)  loss_ce_3_unscaled: 1.4761 (2.0190)  loss_bbox_3_unscaled: 0.0386 (0.0500)  loss_giou_3_unscaled: 0.4676 (0.5181)  cardinality_error_3_unscaled: 4.5000 (18.4510)  loss_ce_4_unscaled: 1.4560 (1.9771)  loss_bbox_4_unscaled: 0.0397 (0.0504)  loss_giou_4_unscaled: 0.4975 (0.5241)  cardinality_error_4_unscaled: 4.5000 (17.0245)  time: 0.7883  data: 0.0281  max mem: 7215
# Epoch: [0]  [ 60/149]  eta: 0:01:11  lr: 0.000100  class_error: 72.97  loss: 15.7853 (19.6702)  loss_ce: 1.2102 (1.8317)  loss_bbox: 0.1942 (0.2527)  loss_giou: 0.9453 (1.0386)  loss_ce_0: 1.6626 (2.2407)  loss_bbox_0: 0.2006 (0.2614)  loss_giou_0: 1.0240 (1.0632)  loss_ce_1: 1.4934 (2.1066)  loss_bbox_1: 0.2010 (0.2499)  loss_giou_1: 0.9576 (1.0313)  loss_ce_2: 1.3576 (1.9785)  loss_bbox_2: 0.2074 (0.2526)  loss_giou_2: 0.9521 (1.0304)  loss_ce_3: 1.2903 (1.9066)  loss_bbox_3: 0.1894 (0.2475)  loss_giou_3: 0.9109 (1.0255)  loss_ce_4: 1.2439 (1.8667)  loss_bbox_4: 0.1741 (0.2492)  loss_giou_4: 0.9507 (1.0372)  loss_ce_unscaled: 1.2102 (1.8317)  class_error_unscaled: 75.7576 (90.5438)  loss_bbox_unscaled: 0.0388 (0.0505)  loss_giou_unscaled: 0.4726 (0.5193)  cardinality_error_unscaled: 4.0000 (14.3975)  loss_ce_0_unscaled: 1.6626 (2.2407)  loss_bbox_0_unscaled: 0.0401 (0.0523)  loss_giou_0_unscaled: 0.5120 (0.5316)  cardinality_error_0_unscaled: 3.7500 (22.8156)  loss_ce_1_unscaled: 1.4934 (2.1066)  loss_bbox_1_unscaled: 0.0402 (0.0500)  loss_giou_1_unscaled: 0.4788 (0.5156)  cardinality_error_1_unscaled: 6.2500 (20.1148)  loss_ce_2_unscaled: 1.3576 (1.9785)  loss_bbox_2_unscaled: 0.0415 (0.0505)  loss_giou_2_unscaled: 0.4761 (0.5152)  cardinality_error_2_unscaled: 4.2500 (17.4590)  loss_ce_3_unscaled: 1.2903 (1.9066)  loss_bbox_3_unscaled: 0.0379 (0.0495)  loss_giou_3_unscaled: 0.4555 (0.5128)  cardinality_error_3_unscaled: 3.2500 (16.0041)  loss_ce_4_unscaled: 1.2439 (1.8667)  loss_bbox_4_unscaled: 0.0348 (0.0498)  loss_giou_4_unscaled: 0.4754 (0.5186)  cardinality_error_4_unscaled: 4.0000 (14.8893)  time: 0.7683  data: 0.0275  max mem: 7215
# Epoch: [0]  [ 70/149]  eta: 0:01:02  lr: 0.000100  class_error: 76.92  loss: 15.4265 (19.2410)  loss_ce: 1.2021 (1.7654)  loss_bbox: 0.2170 (0.2553)  loss_giou: 0.9453 (1.0403)  loss_ce_0: 1.5501 (2.1531)  loss_bbox_0: 0.2103 (0.2618)  loss_giou_0: 1.0099 (1.0636)  loss_ce_1: 1.3872 (2.0227)  loss_bbox_1: 0.2223 (0.2520)  loss_giou_1: 0.9386 (1.0312)  loss_ce_2: 1.3116 (1.9024)  loss_bbox_2: 0.2391 (0.2550)  loss_giou_2: 0.9470 (1.0344)  loss_ce_3: 1.2680 (1.8359)  loss_bbox_3: 0.2259 (0.2502)  loss_giou_3: 0.9109 (1.0288)  loss_ce_4: 1.2149 (1.7978)  loss_bbox_4: 0.2209 (0.2526)  loss_giou_4: 0.9416 (1.0385)  loss_ce_unscaled: 1.2021 (1.7654)  class_error_unscaled: 81.8182 (89.6185)  loss_bbox_unscaled: 0.0434 (0.0511)  loss_giou_unscaled: 0.4726 (0.5201)  cardinality_error_unscaled: 4.7500 (13.1197)  loss_ce_0_unscaled: 1.5501 (2.1531)  loss_bbox_0_unscaled: 0.0421 (0.0524)  loss_giou_0_unscaled: 0.5050 (0.5318)  cardinality_error_0_unscaled: 4.0000 (20.4085)  loss_ce_1_unscaled: 1.3872 (2.0227)  loss_bbox_1_unscaled: 0.0445 (0.0504)  loss_giou_1_unscaled: 0.4693 (0.5156)  cardinality_error_1_unscaled: 4.5000 (18.0387)  loss_ce_2_unscaled: 1.3116 (1.9024)  loss_bbox_2_unscaled: 0.0478 (0.0510)  loss_giou_2_unscaled: 0.4735 (0.5172)  cardinality_error_2_unscaled: 4.2500 (15.7676)  loss_ce_3_unscaled: 1.2680 (1.8359)  loss_bbox_3_unscaled: 0.0452 (0.0500)  loss_giou_3_unscaled: 0.4555 (0.5144)  cardinality_error_3_unscaled: 4.2500 (14.5246)  loss_ce_4_unscaled: 1.2149 (1.7978)  loss_bbox_4_unscaled: 0.0442 (0.0505)  loss_giou_4_unscaled: 0.4708 (0.5192)  cardinality_error_4_unscaled: 4.7500 (13.5845)  time: 0.7938  data: 0.0289  max mem: 7215
# Epoch: [0]  [ 80/149]  eta: 0:00:54  lr: 0.000100  class_error: 57.14  loss: 14.6360 (18.7004)  loss_ce: 1.1907 (1.6964)  loss_bbox: 0.2192 (0.2523)  loss_giou: 0.9896 (1.0336)  loss_ce_0: 1.4809 (2.0645)  loss_bbox_0: 0.2340 (0.2575)  loss_giou_0: 0.9770 (1.0513)  loss_ce_1: 1.3624 (1.9393)  loss_bbox_1: 0.2369 (0.2489)  loss_giou_1: 0.9156 (1.0210)  loss_ce_2: 1.2732 (1.8262)  loss_bbox_2: 0.2208 (0.2515)  loss_giou_2: 0.9470 (1.0235)  loss_ce_3: 1.2282 (1.7614)  loss_bbox_3: 0.2342 (0.2480)  loss_giou_3: 0.9481 (1.0204)  loss_ce_4: 1.2064 (1.7258)  loss_bbox_4: 0.2301 (0.2497)  loss_giou_4: 0.9659 (1.0293)  loss_ce_unscaled: 1.1907 (1.6964)  class_error_unscaled: 83.3333 (88.9535)  loss_bbox_unscaled: 0.0438 (0.0505)  loss_giou_unscaled: 0.4948 (0.5168)  cardinality_error_unscaled: 3.5000 (12.0432)  loss_ce_0_unscaled: 1.4809 (2.0645)  loss_bbox_0_unscaled: 0.0468 (0.0515)  loss_giou_0_unscaled: 0.4885 (0.5256)  cardinality_error_0_unscaled: 4.0000 (18.4105)  loss_ce_1_unscaled: 1.3624 (1.9393)  loss_bbox_1_unscaled: 0.0474 (0.0498)  loss_giou_1_unscaled: 0.4578 (0.5105)  cardinality_error_1_unscaled: 3.7500 (16.3426)  loss_ce_2_unscaled: 1.2732 (1.8262)  loss_bbox_2_unscaled: 0.0442 (0.0503)  loss_giou_2_unscaled: 0.4735 (0.5118)  cardinality_error_2_unscaled: 3.2500 (14.2932)  loss_ce_3_unscaled: 1.2282 (1.7614)  loss_bbox_3_unscaled: 0.0468 (0.0496)  loss_giou_3_unscaled: 0.4741 (0.5102)  cardinality_error_3_unscaled: 4.2500 (13.1790)  loss_ce_4_unscaled: 1.2064 (1.7258)  loss_bbox_4_unscaled: 0.0460 (0.0499)  loss_giou_4_unscaled: 0.4830 (0.5146)  cardinality_error_4_unscaled: 3.7500 (12.3920)  time: 0.7729  data: 0.0257  max mem: 7215
# Epoch: [0]  [ 90/149]  eta: 0:00:47  lr: 0.000100  class_error: 71.43  loss: 14.2230 (18.2440)  loss_ce: 1.1759 (1.6507)  loss_bbox: 0.2057 (0.2467)  loss_giou: 0.9502 (1.0189)  loss_ce_0: 1.4265 (2.0023)  loss_bbox_0: 0.2005 (0.2508)  loss_giou_0: 0.9427 (1.0340)  loss_ce_1: 1.2839 (1.8800)  loss_bbox_1: 0.1882 (0.2429)  loss_giou_1: 0.9176 (1.0032)  loss_ce_2: 1.2259 (1.7730)  loss_bbox_2: 0.1920 (0.2460)  loss_giou_2: 0.9270 (1.0048)  loss_ce_3: 1.1871 (1.7100)  loss_bbox_3: 0.1941 (0.2427)  loss_giou_3: 0.8850 (1.0027)  loss_ce_4: 1.1825 (1.6777)  loss_bbox_4: 0.1874 (0.2441)  loss_giou_4: 0.9387 (1.0137)  loss_ce_unscaled: 1.1759 (1.6507)  class_error_unscaled: 80.0000 (87.3894)  loss_bbox_unscaled: 0.0411 (0.0493)  loss_giou_unscaled: 0.4751 (0.5094)  cardinality_error_unscaled: 3.5000 (11.1429)  loss_ce_0_unscaled: 1.4265 (2.0023)  loss_bbox_0_unscaled: 0.0401 (0.0502)  loss_giou_0_unscaled: 0.4713 (0.5170)  cardinality_error_0_unscaled: 3.2500 (16.7857)  loss_ce_1_unscaled: 1.2839 (1.8800)  loss_bbox_1_unscaled: 0.0376 (0.0486)  loss_giou_1_unscaled: 0.4588 (0.5016)  cardinality_error_1_unscaled: 3.2500 (14.9615)  loss_ce_2_unscaled: 1.2259 (1.7730)  loss_bbox_2_unscaled: 0.0384 (0.0492)  loss_giou_2_unscaled: 0.4635 (0.5024)  cardinality_error_2_unscaled: 3.2500 (13.1154)  loss_ce_3_unscaled: 1.1871 (1.7100)  loss_bbox_3_unscaled: 0.0388 (0.0485)  loss_giou_3_unscaled: 0.4425 (0.5013)  cardinality_error_3_unscaled: 3.0000 (12.1291)  loss_ce_4_unscaled: 1.1825 (1.6777)  loss_bbox_4_unscaled: 0.0375 (0.0488)  loss_giou_4_unscaled: 0.4694 (0.5068)  cardinality_error_4_unscaled: 3.2500 (11.4588)  time: 0.7956  data: 0.0279  max mem: 7215
# Epoch: [0]  [100/149]  eta: 0:00:39  lr: 0.000100  class_error: 83.33  loss: 14.6460 (17.9990)  loss_ce: 1.2238 (1.6155)  loss_bbox: 0.2207 (0.2490)  loss_giou: 0.8627 (1.0197)  loss_ce_0: 1.4677 (1.9503)  loss_bbox_0: 0.2036 (0.2520)  loss_giou_0: 0.9427 (1.0305)  loss_ce_1: 1.3845 (1.8347)  loss_bbox_1: 0.2029 (0.2448)  loss_giou_1: 0.9180 (1.0022)  loss_ce_2: 1.3077 (1.7315)  loss_bbox_2: 0.1980 (0.2470)  loss_giou_2: 0.9021 (1.0042)  loss_ce_3: 1.2462 (1.6716)  loss_bbox_3: 0.2048 (0.2445)  loss_giou_3: 0.8835 (1.0014)  loss_ce_4: 1.2344 (1.6405)  loss_bbox_4: 0.2077 (0.2462)  loss_giou_4: 0.8711 (1.0135)  loss_ce_unscaled: 1.2238 (1.6155)  class_error_unscaled: 72.9730 (86.0663)  loss_bbox_unscaled: 0.0441 (0.0498)  loss_giou_unscaled: 0.4313 (0.5098)  cardinality_error_unscaled: 4.2500 (10.6262)  loss_ce_0_unscaled: 1.4677 (1.9503)  loss_bbox_0_unscaled: 0.0407 (0.0504)  loss_giou_0_unscaled: 0.4713 (0.5153)  cardinality_error_0_unscaled: 3.7500 (15.6163)  loss_ce_1_unscaled: 1.3845 (1.8347)  loss_bbox_1_unscaled: 0.0406 (0.0490)  loss_giou_1_unscaled: 0.4590 (0.5011)  cardinality_error_1_unscaled: 3.2500 (13.9208)  loss_ce_2_unscaled: 1.3077 (1.7315)  loss_bbox_2_unscaled: 0.0396 (0.0494)  loss_giou_2_unscaled: 0.4511 (0.5021)  cardinality_error_2_unscaled: 3.7500 (12.3045)  loss_ce_3_unscaled: 1.2462 (1.6716)  loss_bbox_3_unscaled: 0.0410 (0.0489)  loss_giou_3_unscaled: 0.4418 (0.5007)  cardinality_error_3_unscaled: 4.2500 (11.5371)  loss_ce_4_unscaled: 1.2344 (1.6405)  loss_bbox_4_unscaled: 0.0415 (0.0492)  loss_giou_4_unscaled: 0.4355 (0.5067)  cardinality_error_4_unscaled: 4.5000 (10.9208)  time: 0.8111  data: 0.0277  max mem: 7215
# Epoch: [0]  [110/149]  eta: 0:00:31  lr: 0.000100  class_error: 100.00  loss: 17.3359 (17.9629)  loss_ce: 1.3698 (1.6040)  loss_bbox: 0.2726 (0.2535)  loss_giou: 1.0412 (1.0293)  loss_ce_0: 1.4853 (1.9199)  loss_bbox_0: 0.2512 (0.2558)  loss_giou_0: 1.0247 (1.0399)  loss_ce_1: 1.4983 (1.8115)  loss_bbox_1: 0.2440 (0.2484)  loss_giou_1: 1.0144 (1.0117)  loss_ce_2: 1.4237 (1.7142)  loss_bbox_2: 0.2503 (0.2502)  loss_giou_2: 0.9846 (1.0131)  loss_ce_3: 1.3982 (1.6562)  loss_bbox_3: 0.2660 (0.2484)  loss_giou_3: 0.9637 (1.0090)  loss_ce_4: 1.3837 (1.6267)  loss_bbox_4: 0.2759 (0.2508)  loss_giou_4: 1.0027 (1.0205)  loss_ce_unscaled: 1.3698 (1.6040)  class_error_unscaled: 78.1818 (85.8668)  loss_bbox_unscaled: 0.0545 (0.0507)  loss_giou_unscaled: 0.5206 (0.5147)  cardinality_error_unscaled: 5.0000 (10.1419)  loss_ce_0_unscaled: 1.4853 (1.9199)  loss_bbox_0_unscaled: 0.0502 (0.0512)  loss_giou_0_unscaled: 0.5124 (0.5199)  cardinality_error_0_unscaled: 5.2500 (14.7230)  loss_ce_1_unscaled: 1.4983 (1.8115)  loss_bbox_1_unscaled: 0.0488 (0.0497)  loss_giou_1_unscaled: 0.5072 (0.5058)  cardinality_error_1_unscaled: 5.0000 (13.1622)  loss_ce_2_unscaled: 1.4237 (1.7142)  loss_bbox_2_unscaled: 0.0501 (0.0500)  loss_giou_2_unscaled: 0.4923 (0.5065)  cardinality_error_2_unscaled: 4.7500 (11.6622)  loss_ce_3_unscaled: 1.3982 (1.6562)  loss_bbox_3_unscaled: 0.0532 (0.0497)  loss_giou_3_unscaled: 0.4818 (0.5045)  cardinality_error_3_unscaled: 5.0000 (10.9977)  loss_ce_4_unscaled: 1.3837 (1.6267)  loss_bbox_4_unscaled: 0.0552 (0.0502)  loss_giou_4_unscaled: 0.5013 (0.5102)  cardinality_error_4_unscaled: 5.0000 (10.4234)  time: 0.8342  data: 0.0292  max mem: 7215
# Epoch: [0]  [120/149]  eta: 0:00:23  lr: 0.000100  class_error: 100.00  loss: 15.0513 (17.6011)  loss_ce: 1.2336 (1.5668)  loss_bbox: 0.2251 (0.2500)  loss_giou: 0.9642 (1.0127)  loss_ce_0: 1.4504 (1.8716)  loss_bbox_0: 0.2274 (0.2528)  loss_giou_0: 0.9961 (1.0259)  loss_ce_1: 1.3477 (1.7655)  loss_bbox_1: 0.1890 (0.2443)  loss_giou_1: 0.9695 (0.9962)  loss_ce_2: 1.2504 (1.6713)  loss_bbox_2: 0.2100 (0.2469)  loss_giou_2: 0.8935 (1.0000)  loss_ce_3: 1.2295 (1.6164)  loss_bbox_3: 0.2077 (0.2450)  loss_giou_3: 0.9292 (0.9948)  loss_ce_4: 1.2246 (1.5882)  loss_bbox_4: 0.2181 (0.2473)  loss_giou_4: 0.9154 (1.0054)  loss_ce_unscaled: 1.2336 (1.5668)  class_error_unscaled: 80.0000 (85.1937)  loss_bbox_unscaled: 0.0450 (0.0500)  loss_giou_unscaled: 0.4821 (0.5064)  cardinality_error_unscaled: 4.7500 (9.6570)  loss_ce_0_unscaled: 1.4504 (1.8716)  loss_bbox_0_unscaled: 0.0455 (0.0506)  loss_giou_0_unscaled: 0.4981 (0.5129)  cardinality_error_0_unscaled: 4.5000 (13.7851)  loss_ce_1_unscaled: 1.3477 (1.7655)  loss_bbox_1_unscaled: 0.0378 (0.0489)  loss_giou_1_unscaled: 0.4848 (0.4981)  cardinality_error_1_unscaled: 4.5000 (12.3678)  loss_ce_2_unscaled: 1.2504 (1.6713)  loss_bbox_2_unscaled: 0.0420 (0.0494)  loss_giou_2_unscaled: 0.4468 (0.5000)  cardinality_error_2_unscaled: 4.5000 (10.9669)  loss_ce_3_unscaled: 1.2295 (1.6164)  loss_bbox_3_unscaled: 0.0415 (0.0490)  loss_giou_3_unscaled: 0.4646 (0.4974)  cardinality_error_3_unscaled: 4.5000 (10.4153)  loss_ce_4_unscaled: 1.2246 (1.5882)  loss_bbox_4_unscaled: 0.0436 (0.0495)  loss_giou_4_unscaled: 0.4577 (0.5027)  cardinality_error_4_unscaled: 4.5000 (9.9070)  time: 0.8092  data: 0.0273  max mem: 7230
# Epoch: [0]  [130/149]  eta: 0:00:15  lr: 0.000100  class_error: 69.44  loss: 13.6875 (17.4149)  loss_ce: 1.1221 (1.5389)  loss_bbox: 0.2180 (0.2512)  loss_giou: 0.9587 (1.0138)  loss_ce_0: 1.2352 (1.8319)  loss_bbox_0: 0.2274 (0.2538)  loss_giou_0: 0.9264 (1.0249)  loss_ce_1: 1.1942 (1.7297)  loss_bbox_1: 0.1890 (0.2458)  loss_giou_1: 0.8457 (0.9968)  loss_ce_2: 1.1555 (1.6386)  loss_bbox_2: 0.2005 (0.2483)  loss_giou_2: 0.9037 (1.0005)  loss_ce_3: 1.1333 (1.5863)  loss_bbox_3: 0.1976 (0.2462)  loss_giou_3: 0.8792 (0.9946)  loss_ce_4: 1.1093 (1.5592)  loss_bbox_4: 0.2122 (0.2486)  loss_giou_4: 0.9374 (1.0058)  loss_ce_unscaled: 1.1221 (1.5389)  class_error_unscaled: 71.4286 (83.8157)  loss_bbox_unscaled: 0.0436 (0.0502)  loss_giou_unscaled: 0.4794 (0.5069)  cardinality_error_unscaled: 5.2500 (9.4103)  loss_ce_0_unscaled: 1.2352 (1.8319)  loss_bbox_0_unscaled: 0.0455 (0.0508)  loss_giou_0_unscaled: 0.4632 (0.5124)  cardinality_error_0_unscaled: 3.0000 (13.0344)  loss_ce_1_unscaled: 1.1942 (1.7297)  loss_bbox_1_unscaled: 0.0378 (0.0492)  loss_giou_1_unscaled: 0.4228 (0.4984)  cardinality_error_1_unscaled: 3.2500 (11.7538)  loss_ce_2_unscaled: 1.1555 (1.6386)  loss_bbox_2_unscaled: 0.0401 (0.0497)  loss_giou_2_unscaled: 0.4518 (0.5002)  cardinality_error_2_unscaled: 4.0000 (10.5229)  loss_ce_3_unscaled: 1.1333 (1.5863)  loss_bbox_3_unscaled: 0.0395 (0.0492)  loss_giou_3_unscaled: 0.4396 (0.4973)  cardinality_error_3_unscaled: 4.5000 (10.0992)  loss_ce_4_unscaled: 1.1093 (1.5592)  loss_bbox_4_unscaled: 0.0424 (0.0497)  loss_giou_4_unscaled: 0.4687 (0.5029)  cardinality_error_4_unscaled: 4.2500 (9.6088)  time: 0.8084  data: 0.0294  max mem: 7230
# Epoch: [0]  [140/149]  eta: 0:00:07  lr: 0.000100  class_error: 92.86  loss: 14.0464 (17.1694)  loss_ce: 1.1126 (1.5108)  loss_bbox: 0.2027 (0.2487)  loss_giou: 0.9599 (1.0064)  loss_ce_0: 1.2339 (1.7956)  loss_bbox_0: 0.2300 (0.2516)  loss_giou_0: 0.9758 (1.0169)  loss_ce_1: 1.1942 (1.6951)  loss_bbox_1: 0.1952 (0.2435)  loss_giou_1: 0.9724 (0.9883)  loss_ce_2: 1.1555 (1.6077)  loss_bbox_2: 0.2012 (0.2464)  loss_giou_2: 1.0054 (0.9944)  loss_ce_3: 1.1333 (1.5565)  loss_bbox_3: 0.1955 (0.2440)  loss_giou_3: 0.9609 (0.9883)  loss_ce_4: 1.1093 (1.5310)  loss_bbox_4: 0.2002 (0.2459)  loss_giou_4: 0.9534 (0.9982)  loss_ce_unscaled: 1.1126 (1.5108)  class_error_unscaled: 65.0000 (82.8858)  loss_bbox_unscaled: 0.0405 (0.0497)  loss_giou_unscaled: 0.4800 (0.5032)  cardinality_error_unscaled: 6.0000 (9.1844)  loss_ce_0_unscaled: 1.2339 (1.7956)  loss_bbox_0_unscaled: 0.0460 (0.0503)  loss_giou_0_unscaled: 0.4879 (0.5084)  cardinality_error_0_unscaled: 2.7500 (12.3351)  loss_ce_1_unscaled: 1.1942 (1.6951)  loss_bbox_1_unscaled: 0.0390 (0.0487)  loss_giou_1_unscaled: 0.4862 (0.4942)  cardinality_error_1_unscaled: 3.5000 (11.1631)  loss_ce_2_unscaled: 1.1555 (1.6077)  loss_bbox_2_unscaled: 0.0402 (0.0493)  loss_giou_2_unscaled: 0.5027 (0.4972)  cardinality_error_2_unscaled: 4.5000 (10.0691)  loss_ce_3_unscaled: 1.1333 (1.5565)  loss_bbox_3_unscaled: 0.0391 (0.0488)  loss_giou_3_unscaled: 0.4804 (0.4942)  cardinality_error_3_unscaled: 5.7500 (9.7979)  loss_ce_4_unscaled: 1.1093 (1.5310)  loss_bbox_4_unscaled: 0.0400 (0.0492)  loss_giou_4_unscaled: 0.4767 (0.4991)  cardinality_error_4_unscaled: 5.2500 (9.3493)  time: 0.8275  data: 0.0296  max mem: 7230
# Epoch: [0]  [148/149]  eta: 0:00:00  lr: 0.000100  class_error: 62.50  loss: 12.9401 (16.9818)  loss_ce: 1.0694 (1.4844)  loss_bbox: 0.1911 (0.2468)  loss_giou: 0.9468 (1.0064)  loss_ce_0: 1.2000 (1.7628)  loss_bbox_0: 0.2071 (0.2492)  loss_giou_0: 0.9193 (1.0144)  loss_ce_1: 1.1188 (1.6643)  loss_bbox_1: 0.1869 (0.2411)  loss_giou_1: 0.9207 (0.9876)  loss_ce_2: 1.1078 (1.5796)  loss_bbox_2: 0.1891 (0.2443)  loss_giou_2: 0.9756 (0.9943)  loss_ce_3: 1.0818 (1.5287)  loss_bbox_3: 0.1873 (0.2422)  loss_giou_3: 0.9040 (0.9883)  loss_ce_4: 1.0882 (1.5041)  loss_bbox_4: 0.1894 (0.2439)  loss_giou_4: 0.9435 (0.9995)  loss_ce_unscaled: 1.0694 (1.4844)  class_error_unscaled: 62.5000 (81.9423)  loss_bbox_unscaled: 0.0382 (0.0494)  loss_giou_unscaled: 0.4734 (0.5032)  cardinality_error_unscaled: 3.7500 (8.8473)  loss_ce_0_unscaled: 1.2000 (1.7628)  loss_bbox_0_unscaled: 0.0414 (0.0498)  loss_giou_0_unscaled: 0.4596 (0.5072)  cardinality_error_0_unscaled: 2.5000 (11.8205)  loss_ce_1_unscaled: 1.1188 (1.6643)  loss_bbox_1_unscaled: 0.0374 (0.0482)  loss_giou_1_unscaled: 0.4603 (0.4938)  cardinality_error_1_unscaled: 2.7500 (10.7131)  loss_ce_2_unscaled: 1.1078 (1.5796)  loss_bbox_2_unscaled: 0.0378 (0.0489)  loss_giou_2_unscaled: 0.4878 (0.4972)  cardinality_error_2_unscaled: 3.5000 (9.6678)  loss_ce_3_unscaled: 1.0818 (1.5287)  loss_bbox_3_unscaled: 0.0375 (0.0484)  loss_giou_3_unscaled: 0.4520 (0.4942)  cardinality_error_3_unscaled: 4.5000 (9.4211)  loss_ce_4_unscaled: 1.0882 (1.5041)  loss_bbox_4_unscaled: 0.0379 (0.0488)  loss_giou_4_unscaled: 0.4717 (0.4997)  cardinality_error_4_unscaled: 4.2500 (8.9933)  time: 0.7840  data: 0.0244  max mem: 7230
# Epoch: [0] Total time: 0:01:59 (0.8040 s / it)
# Averaged stats: lr: 0.000100  class_error: 62.50  loss: 12.9401 (16.9818)  loss_ce: 1.0694 (1.4844)  loss_bbox: 0.1911 (0.2468)  loss_giou: 0.9468 (1.0064)  loss_ce_0: 1.2000 (1.7628)  loss_bbox_0: 0.2071 (0.2492)  loss_giou_0: 0.9193 (1.0144)  loss_ce_1: 1.1188 (1.6643)  loss_bbox_1: 0.1869 (0.2411)  loss_giou_1: 0.9207 (0.9876)  loss_ce_2: 1.1078 (1.5796)  loss_bbox_2: 0.1891 (0.2443)  loss_giou_2: 0.9756 (0.9943)  loss_ce_3: 1.0818 (1.5287)  loss_bbox_3: 0.1873 (0.2422)  loss_giou_3: 0.9040 (0.9883)  loss_ce_4: 1.0882 (1.5041)  loss_bbox_4: 0.1894 (0.2439)  loss_giou_4: 0.9435 (0.9995)  loss_ce_unscaled: 1.0694 (1.4844)  class_error_unscaled: 62.5000 (81.9423)  loss_bbox_unscaled: 0.0382 (0.0494)  loss_giou_unscaled: 0.4734 (0.5032)  cardinality_error_unscaled: 3.7500 (8.8473)  loss_ce_0_unscaled: 1.2000 (1.7628)  loss_bbox_0_unscaled: 0.0414 (0.0498)  loss_giou_0_unscaled: 0.4596 (0.5072)  cardinality_error_0_unscaled: 2.5000 (11.8205)  loss_ce_1_unscaled: 1.1188 (1.6643)  loss_bbox_1_unscaled: 0.0374 (0.0482)  loss_giou_1_unscaled: 0.4603 (0.4938)  cardinality_error_1_unscaled: 2.7500 (10.7131)  loss_ce_2_unscaled: 1.1078 (1.5796)  loss_bbox_2_unscaled: 0.0378 (0.0489)  loss_giou_2_unscaled: 0.4878 (0.4972)  cardinality_error_2_unscaled: 3.5000 (9.6678)  loss_ce_3_unscaled: 1.0818 (1.5287)  loss_bbox_3_unscaled: 0.0375 (0.0484)  loss_giou_3_unscaled: 0.4520 (0.4942)  cardinality_error_3_unscaled: 4.5000 (9.4211)  loss_ce_4_unscaled: 1.0882 (1.5041)  loss_bbox_4_unscaled: 0.0379 (0.0488)  loss_giou_4_unscaled: 0.4717 (0.4997)  cardinality_error_4_unscaled: 4.2500 (8.9933)
# Test:  [ 0/37]  eta: 0:00:55  class_error: 80.00  loss: 17.7309 (17.7309)  loss_ce: 1.5234 (1.5234)  loss_bbox: 0.3646 (0.3646)  loss_giou: 1.1284 (1.1284)  loss_ce_0: 1.5643 (1.5643)  loss_bbox_0: 0.3247 (0.3247)  loss_giou_0: 1.0824 (1.0824)  loss_ce_1: 1.5425 (1.5425)  loss_bbox_1: 0.3309 (0.3309)  loss_giou_1: 1.0633 (1.0633)  loss_ce_2: 1.5360 (1.5360)  loss_bbox_2: 0.3438 (0.3438)  loss_giou_2: 1.0865 (1.0865)  loss_ce_3: 1.5021 (1.5021)  loss_bbox_3: 0.3229 (0.3229)  loss_giou_3: 1.0469 (1.0469)  loss_ce_4: 1.5324 (1.5324)  loss_bbox_4: 0.3460 (0.3460)  loss_giou_4: 1.0898 (1.0898)  loss_ce_unscaled: 1.5234 (1.5234)  class_error_unscaled: 80.0000 (80.0000)  loss_bbox_unscaled: 0.0729 (0.0729)  loss_giou_unscaled: 0.5642 (0.5642)  cardinality_error_unscaled: 4.5000 (4.5000)  loss_ce_0_unscaled: 1.5643 (1.5643)  loss_bbox_0_unscaled: 0.0649 (0.0649)  loss_giou_0_unscaled: 0.5412 (0.5412)  cardinality_error_0_unscaled: 4.2500 (4.2500)  loss_ce_1_unscaled: 1.5425 (1.5425)  loss_bbox_1_unscaled: 0.0662 (0.0662)  loss_giou_1_unscaled: 0.5317 (0.5317)  cardinality_error_1_unscaled: 4.5000 (4.5000)  loss_ce_2_unscaled: 1.5360 (1.5360)  loss_bbox_2_unscaled: 0.0688 (0.0688)  loss_giou_2_unscaled: 0.5433 (0.5433)  cardinality_error_2_unscaled: 3.0000 (3.0000)  loss_ce_3_unscaled: 1.5021 (1.5021)  loss_bbox_3_unscaled: 0.0646 (0.0646)  loss_giou_3_unscaled: 0.5235 (0.5235)  cardinality_error_3_unscaled: 5.0000 (5.0000)  loss_ce_4_unscaled: 1.5324 (1.5324)  loss_bbox_4_unscaled: 0.0692 (0.0692)  loss_giou_4_unscaled: 0.5449 (0.5449)  cardinality_error_4_unscaled: 4.5000 (4.5000)  time: 1.5039  data: 0.7914  max mem: 7230
# Test:  [10/37]  eta: 0:00:18  class_error: 81.82  loss: 18.5238 (18.6003)  loss_ce: 1.6445 (1.6487)  loss_bbox: 0.2079 (0.2203)  loss_giou: 1.2127 (1.2424)  loss_ce_0: 1.8227 (1.7995)  loss_bbox_0: 0.2100 (0.2090)  loss_giou_0: 1.1539 (1.1460)  loss_ce_1: 1.8106 (1.7756)  loss_bbox_1: 0.1976 (0.2068)  loss_giou_1: 1.1511 (1.1484)  loss_ce_2: 1.7696 (1.7300)  loss_bbox_2: 0.1949 (0.2108)  loss_giou_2: 1.1671 (1.1826)  loss_ce_3: 1.7065 (1.6873)  loss_bbox_3: 0.2035 (0.2066)  loss_giou_3: 1.1310 (1.1416)  loss_ce_4: 1.6778 (1.6653)  loss_bbox_4: 0.1993 (0.2128)  loss_giou_4: 1.1381 (1.1665)  loss_ce_unscaled: 1.6445 (1.6487)  class_error_unscaled: 80.0000 (75.0558)  loss_bbox_unscaled: 0.0416 (0.0441)  loss_giou_unscaled: 0.6063 (0.6212)  cardinality_error_unscaled: 7.2500 (7.8182)  loss_ce_0_unscaled: 1.8227 (1.7995)  loss_bbox_0_unscaled: 0.0420 (0.0418)  loss_giou_0_unscaled: 0.5769 (0.5730)  cardinality_error_0_unscaled: 7.2500 (7.4318)  loss_ce_1_unscaled: 1.8106 (1.7756)  loss_bbox_1_unscaled: 0.0395 (0.0414)  loss_giou_1_unscaled: 0.5756 (0.5742)  cardinality_error_1_unscaled: 7.0000 (6.6136)  loss_ce_2_unscaled: 1.7696 (1.7300)  loss_bbox_2_unscaled: 0.0390 (0.0422)  loss_giou_2_unscaled: 0.5836 (0.5913)  cardinality_error_2_unscaled: 7.2500 (6.7500)  loss_ce_3_unscaled: 1.7065 (1.6873)  loss_bbox_3_unscaled: 0.0407 (0.0413)  loss_giou_3_unscaled: 0.5655 (0.5708)  cardinality_error_3_unscaled: 7.5000 (7.7955)  loss_ce_4_unscaled: 1.6778 (1.6653)  loss_bbox_4_unscaled: 0.0399 (0.0426)  loss_giou_4_unscaled: 0.5690 (0.5832)  cardinality_error_4_unscaled: 7.7500 (7.6136)  time: 0.6951  data: 0.1158  max mem: 7230
# Test:  [20/37]  eta: 0:00:10  class_error: 69.23  loss: 18.3278 (17.3075)  loss_ce: 1.5394 (1.5148)  loss_bbox: 0.2064 (0.2086)  loss_giou: 1.2017 (1.1713)  loss_ce_0: 1.7289 (1.6778)  loss_bbox_0: 0.2085 (0.2004)  loss_giou_0: 1.0887 (1.0865)  loss_ce_1: 1.7109 (1.6287)  loss_bbox_1: 0.1887 (0.1971)  loss_giou_1: 1.0860 (1.0876)  loss_ce_2: 1.6322 (1.5801)  loss_bbox_2: 0.1891 (0.1992)  loss_giou_2: 1.1143 (1.1176)  loss_ce_3: 1.5934 (1.5459)  loss_bbox_3: 0.1941 (0.1953)  loss_giou_3: 1.0673 (1.0722)  loss_ce_4: 1.5624 (1.5259)  loss_bbox_4: 0.1961 (0.1999)  loss_giou_4: 1.1020 (1.0985)  loss_ce_unscaled: 1.5394 (1.5148)  class_error_unscaled: 65.3333 (65.5778)  loss_bbox_unscaled: 0.0413 (0.0417)  loss_giou_unscaled: 0.6008 (0.5857)  cardinality_error_unscaled: 6.5000 (7.9524)  loss_ce_0_unscaled: 1.7289 (1.6778)  loss_bbox_0_unscaled: 0.0417 (0.0401)  loss_giou_0_unscaled: 0.5443 (0.5432)  cardinality_error_0_unscaled: 6.2500 (6.7381)  loss_ce_1_unscaled: 1.7109 (1.6287)  loss_bbox_1_unscaled: 0.0377 (0.0394)  loss_giou_1_unscaled: 0.5430 (0.5438)  cardinality_error_1_unscaled: 6.0000 (6.3929)  loss_ce_2_unscaled: 1.6322 (1.5801)  loss_bbox_2_unscaled: 0.0378 (0.0398)  loss_giou_2_unscaled: 0.5571 (0.5588)  cardinality_error_2_unscaled: 6.7500 (6.8095)  loss_ce_3_unscaled: 1.5934 (1.5459)  loss_bbox_3_unscaled: 0.0388 (0.0391)  loss_giou_3_unscaled: 0.5336 (0.5361)  cardinality_error_3_unscaled: 7.0000 (7.8214)  loss_ce_4_unscaled: 1.5624 (1.5259)  loss_bbox_4_unscaled: 0.0392 (0.0400)  loss_giou_4_unscaled: 0.5510 (0.5492)  cardinality_error_4_unscaled: 7.5000 (7.7857)  time: 0.5462  data: 0.0370  max mem: 7230
# Test:  [30/37]  eta: 0:00:03  class_error: 58.33  loss: 16.0618 (16.8001)  loss_ce: 1.3913 (1.4512)  loss_bbox: 0.2080 (0.2154)  loss_giou: 1.0878 (1.1518)  loss_ce_0: 1.5086 (1.6011)  loss_bbox_0: 0.2077 (0.2037)  loss_giou_0: 1.0680 (1.0650)  loss_ce_1: 1.4533 (1.5495)  loss_bbox_1: 0.1971 (0.2042)  loss_giou_1: 1.0286 (1.0689)  loss_ce_2: 1.4116 (1.5035)  loss_bbox_2: 0.1959 (0.2058)  loss_giou_2: 1.0662 (1.0970)  loss_ce_3: 1.3923 (1.4743)  loss_bbox_3: 0.1959 (0.2013)  loss_giou_3: 1.0006 (1.0587)  loss_ce_4: 1.3828 (1.4586)  loss_bbox_4: 0.1972 (0.2068)  loss_giou_4: 1.0387 (1.0835)  loss_ce_unscaled: 1.3913 (1.4512)  class_error_unscaled: 65.3333 (67.0230)  loss_bbox_unscaled: 0.0416 (0.0431)  loss_giou_unscaled: 0.5439 (0.5759)  cardinality_error_unscaled: 4.7500 (6.7903)  loss_ce_0_unscaled: 1.5086 (1.6011)  loss_bbox_0_unscaled: 0.0415 (0.0407)  loss_giou_0_unscaled: 0.5340 (0.5325)  cardinality_error_0_unscaled: 5.0000 (5.9032)  loss_ce_1_unscaled: 1.4533 (1.5495)  loss_bbox_1_unscaled: 0.0394 (0.0408)  loss_giou_1_unscaled: 0.5143 (0.5344)  cardinality_error_1_unscaled: 4.5000 (5.5000)  loss_ce_2_unscaled: 1.4116 (1.5035)  loss_bbox_2_unscaled: 0.0392 (0.0412)  loss_giou_2_unscaled: 0.5331 (0.5485)  cardinality_error_2_unscaled: 5.2500 (6.0565)  loss_ce_3_unscaled: 1.3923 (1.4743)  loss_bbox_3_unscaled: 0.0392 (0.0403)  loss_giou_3_unscaled: 0.5003 (0.5294)  cardinality_error_3_unscaled: 5.0000 (6.8387)  loss_ce_4_unscaled: 1.3828 (1.4586)  loss_bbox_4_unscaled: 0.0394 (0.0414)  loss_giou_4_unscaled: 0.5194 (0.5418)  cardinality_error_4_unscaled: 5.0000 (6.6613)  time: 0.4661  data: 0.0263  max mem: 7230
# Test:  [36/37]  eta: 0:00:00  class_error: 100.00  loss: 15.4928 (16.0351)  loss_ce: 1.2262 (1.3386)  loss_bbox: 0.2301 (0.2301)  loss_giou: 1.0878 (1.1304)  loss_ce_0: 1.3292 (1.4816)  loss_bbox_0: 0.2143 (0.2109)  loss_giou_0: 0.9810 (1.0460)  loss_ce_1: 1.2998 (1.4283)  loss_bbox_1: 0.2123 (0.2073)  loss_giou_1: 0.9701 (1.0439)  loss_ce_2: 1.2254 (1.3850)  loss_bbox_2: 0.2079 (0.2155)  loss_giou_2: 1.0161 (1.0819)  loss_ce_3: 1.2156 (1.3569)  loss_bbox_3: 0.2039 (0.2108)  loss_giou_3: 1.0006 (1.0406)  loss_ce_4: 1.2164 (1.3436)  loss_bbox_4: 0.2164 (0.2184)  loss_giou_4: 1.0230 (1.0654)  loss_ce_unscaled: 1.2262 (1.3386)  class_error_unscaled: 69.6970 (67.9656)  loss_bbox_unscaled: 0.0460 (0.0460)  loss_giou_unscaled: 0.5439 (0.5652)  cardinality_error_unscaled: 4.0000 (5.8919)  loss_ce_0_unscaled: 1.3292 (1.4816)  loss_bbox_0_unscaled: 0.0429 (0.0422)  loss_giou_0_unscaled: 0.4905 (0.5230)  cardinality_error_0_unscaled: 3.2500 (5.1959)  loss_ce_1_unscaled: 1.2998 (1.4283)  loss_bbox_1_unscaled: 0.0425 (0.0415)  loss_giou_1_unscaled: 0.4850 (0.5220)  cardinality_error_1_unscaled: 3.0000 (4.8176)  loss_ce_2_unscaled: 1.2254 (1.3850)  loss_bbox_2_unscaled: 0.0416 (0.0431)  loss_giou_2_unscaled: 0.5081 (0.5409)  cardinality_error_2_unscaled: 4.2500 (5.2703)  loss_ce_3_unscaled: 1.2156 (1.3569)  loss_bbox_3_unscaled: 0.0408 (0.0422)  loss_giou_3_unscaled: 0.5003 (0.5203)  cardinality_error_3_unscaled: 4.5000 (5.9595)  loss_ce_4_unscaled: 1.2164 (1.3436)  loss_bbox_4_unscaled: 0.0433 (0.0437)  loss_giou_4_unscaled: 0.5115 (0.5327)  cardinality_error_4_unscaled: 4.0000 (5.7770)  time: 0.4720  data: 0.0285  max mem: 7230
# Test: Total time: 0:00:20 (0.5407 s / it)
# Averaged stats: class_error: 100.00  loss: 15.4928 (16.0351)  loss_ce: 1.2262 (1.3386)  loss_bbox: 0.2301 (0.2301)  loss_giou: 1.0878 (1.1304)  loss_ce_0: 1.3292 (1.4816)  loss_bbox_0: 0.2143 (0.2109)  loss_giou_0: 0.9810 (1.0460)  loss_ce_1: 1.2998 (1.4283)  loss_bbox_1: 0.2123 (0.2073)  loss_giou_1: 0.9701 (1.0439)  loss_ce_2: 1.2254 (1.3850)  loss_bbox_2: 0.2079 (0.2155)  loss_giou_2: 1.0161 (1.0819)  loss_ce_3: 1.2156 (1.3569)  loss_bbox_3: 0.2039 (0.2108)  loss_giou_3: 1.0006 (1.0406)  loss_ce_4: 1.2164 (1.3436)  loss_bbox_4: 0.2164 (0.2184)  loss_giou_4: 1.0230 (1.0654)  loss_ce_unscaled: 1.2262 (1.3386)  class_error_unscaled: 69.6970 (67.9656)  loss_bbox_unscaled: 0.0460 (0.0460)  loss_giou_unscaled: 0.5439 (0.5652)  cardinality_error_unscaled: 4.0000 (5.8919)  loss_ce_0_unscaled: 1.3292 (1.4816)  loss_bbox_0_unscaled: 0.0429 (0.0422)  loss_giou_0_unscaled: 0.4905 (0.5230)  cardinality_error_0_unscaled: 3.2500 (5.1959)  loss_ce_1_unscaled: 1.2998 (1.4283)  loss_bbox_1_unscaled: 0.0425 (0.0415)  loss_giou_1_unscaled: 0.4850 (0.5220)  cardinality_error_1_unscaled: 3.0000 (4.8176)  loss_ce_2_unscaled: 1.2254 (1.3850)  loss_bbox_2_unscaled: 0.0416 (0.0431)  loss_giou_2_unscaled: 0.5081 (0.5409)  cardinality_error_2_unscaled: 4.2500 (5.2703)  loss_ce_3_unscaled: 1.2156 (1.3569)  loss_bbox_3_unscaled: 0.0408 (0.0422)  loss_giou_3_unscaled: 0.5003 (0.5203)  cardinality_error_3_unscaled: 4.5000 (5.9595)  loss_ce_4_unscaled: 1.2164 (1.3436)  loss_bbox_4_unscaled: 0.0433 (0.0437)  loss_giou_4_unscaled: 0.5115 (0.5327)  cardinality_error_4_unscaled: 4.0000 (5.7770)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.039
# Epoch: [1]  [  0/149]  eta: 0:04:54  lr: 0.000100  class_error: 65.00  loss: 11.7863 (11.7863)  loss_ce: 0.9249 (0.9249)  loss_bbox: 0.2422 (0.2422)  loss_giou: 0.8806 (0.8806)  loss_ce_0: 1.0874 (1.0874)  loss_bbox_0: 0.1854 (0.1854)  loss_giou_0: 0.7630 (0.7630)  loss_ce_1: 1.0017 (1.0017)  loss_bbox_1: 0.1771 (0.1771)  loss_giou_1: 0.6850 (0.6850)  loss_ce_2: 0.9753 (0.9753)  loss_bbox_2: 0.1869 (0.1869)  loss_giou_2: 0.7911 (0.7911)  loss_ce_3: 0.9512 (0.9512)  loss_bbox_3: 0.2179 (0.2179)  loss_giou_3: 0.7755 (0.7755)  loss_ce_4: 0.9184 (0.9184)  loss_bbox_4: 0.2264 (0.2264)  loss_giou_4: 0.7962 (0.7962)  loss_ce_unscaled: 0.9249 (0.9249)  class_error_unscaled: 65.0000 (65.0000)  loss_bbox_unscaled: 0.0484 (0.0484)  loss_giou_unscaled: 0.4403 (0.4403)  cardinality_error_unscaled: 2.7500 (2.7500)  loss_ce_0_unscaled: 1.0874 (1.0874)  loss_bbox_0_unscaled: 0.0371 (0.0371)  loss_giou_0_unscaled: 0.3815 (0.3815)  cardinality_error_0_unscaled: 2.0000 (2.0000)  loss_ce_1_unscaled: 1.0017 (1.0017)  loss_bbox_1_unscaled: 0.0354 (0.0354)  loss_giou_1_unscaled: 0.3425 (0.3425)  cardinality_error_1_unscaled: 1.2500 (1.2500)  loss_ce_2_unscaled: 0.9753 (0.9753)  loss_bbox_2_unscaled: 0.0374 (0.0374)  loss_giou_2_unscaled: 0.3956 (0.3956)  cardinality_error_2_unscaled: 1.7500 (1.7500)  loss_ce_3_unscaled: 0.9512 (0.9512)  loss_bbox_3_unscaled: 0.0436 (0.0436)  loss_giou_3_unscaled: 0.3877 (0.3877)  cardinality_error_3_unscaled: 1.2500 (1.2500)  loss_ce_4_unscaled: 0.9184 (0.9184)  loss_bbox_4_unscaled: 0.0453 (0.0453)  loss_giou_4_unscaled: 0.3981 (0.3981)  cardinality_error_4_unscaled: 2.0000 (2.0000)  time: 1.9758  data: 0.8625  max mem: 7230
# Epoch: [1]  [ 10/149]  eta: 0:02:09  lr: 0.000100  class_error: 60.00  loss: 13.2674 (14.0760)  loss_ce: 1.0010 (1.1267)  loss_bbox: 0.2055 (0.2025)  loss_giou: 0.9602 (1.0047)  loss_ce_0: 1.2085 (1.2957)  loss_bbox_0: 0.1971 (0.2016)  loss_giou_0: 0.9308 (0.9610)  loss_ce_1: 1.0919 (1.2139)  loss_bbox_1: 0.2023 (0.1928)  loss_giou_1: 0.9476 (0.9517)  loss_ce_2: 1.0292 (1.1693)  loss_bbox_2: 0.1967 (0.1925)  loss_giou_2: 0.8972 (0.9490)  loss_ce_3: 0.9987 (1.1519)  loss_bbox_3: 0.2082 (0.2045)  loss_giou_3: 0.8926 (0.9556)  loss_ce_4: 1.0081 (1.1309)  loss_bbox_4: 0.2014 (0.2004)  loss_giou_4: 0.9693 (0.9712)  loss_ce_unscaled: 1.0010 (1.1267)  class_error_unscaled: 64.5161 (67.9284)  loss_bbox_unscaled: 0.0411 (0.0405)  loss_giou_unscaled: 0.4801 (0.5024)  cardinality_error_unscaled: 3.7500 (5.0227)  loss_ce_0_unscaled: 1.2085 (1.2957)  loss_bbox_0_unscaled: 0.0394 (0.0403)  loss_giou_0_unscaled: 0.4654 (0.4805)  cardinality_error_0_unscaled: 3.7500 (4.5682)  loss_ce_1_unscaled: 1.0919 (1.2139)  loss_bbox_1_unscaled: 0.0405 (0.0386)  loss_giou_1_unscaled: 0.4738 (0.4758)  cardinality_error_1_unscaled: 3.7500 (4.2955)  loss_ce_2_unscaled: 1.0292 (1.1693)  loss_bbox_2_unscaled: 0.0393 (0.0385)  loss_giou_2_unscaled: 0.4486 (0.4745)  cardinality_error_2_unscaled: 3.5000 (4.5909)  loss_ce_3_unscaled: 0.9987 (1.1519)  loss_bbox_3_unscaled: 0.0416 (0.0409)  loss_giou_3_unscaled: 0.4463 (0.4778)  cardinality_error_3_unscaled: 3.5000 (5.0455)  loss_ce_4_unscaled: 1.0081 (1.1309)  loss_bbox_4_unscaled: 0.0403 (0.0401)  loss_giou_4_unscaled: 0.4846 (0.4856)  cardinality_error_4_unscaled: 4.0000 (4.9091)  time: 0.9335  data: 0.1001  max mem: 7230
# Epoch: [1]  [ 20/149]  eta: 0:01:52  lr: 0.000100  class_error: 53.85  loss: 13.3553 (14.0840)  loss_ce: 1.0010 (1.1009)  loss_bbox: 0.2055 (0.2166)  loss_giou: 0.9759 (1.0032)  loss_ce_0: 1.2085 (1.2592)  loss_bbox_0: 0.2206 (0.2230)  loss_giou_0: 1.0166 (0.9922)  loss_ce_1: 1.0919 (1.1771)  loss_bbox_1: 0.2034 (0.2104)  loss_giou_1: 0.9476 (0.9669)  loss_ce_2: 1.0292 (1.1366)  loss_bbox_2: 0.2107 (0.2118)  loss_giou_2: 0.9346 (0.9604)  loss_ce_3: 0.9987 (1.1191)  loss_bbox_3: 0.2082 (0.2189)  loss_giou_3: 0.9500 (0.9746)  loss_ce_4: 1.0081 (1.1062)  loss_bbox_4: 0.2150 (0.2159)  loss_giou_4: 0.9758 (0.9910)  loss_ce_unscaled: 1.0010 (1.1009)  class_error_unscaled: 62.5000 (65.8356)  loss_bbox_unscaled: 0.0411 (0.0433)  loss_giou_unscaled: 0.4879 (0.5016)  cardinality_error_unscaled: 3.7500 (4.8095)  loss_ce_0_unscaled: 1.2085 (1.2592)  loss_bbox_0_unscaled: 0.0441 (0.0446)  loss_giou_0_unscaled: 0.5083 (0.4961)  cardinality_error_0_unscaled: 3.0000 (4.2738)  loss_ce_1_unscaled: 1.0919 (1.1771)  loss_bbox_1_unscaled: 0.0407 (0.0421)  loss_giou_1_unscaled: 0.4738 (0.4834)  cardinality_error_1_unscaled: 3.7500 (4.2381)  loss_ce_2_unscaled: 1.0292 (1.1366)  loss_bbox_2_unscaled: 0.0421 (0.0424)  loss_giou_2_unscaled: 0.4673 (0.4802)  cardinality_error_2_unscaled: 3.5000 (4.5833)  loss_ce_3_unscaled: 0.9987 (1.1191)  loss_bbox_3_unscaled: 0.0416 (0.0438)  loss_giou_3_unscaled: 0.4750 (0.4873)  cardinality_error_3_unscaled: 3.5000 (5.0000)  loss_ce_4_unscaled: 1.0081 (1.1062)  loss_bbox_4_unscaled: 0.0430 (0.0432)  loss_giou_4_unscaled: 0.4879 (0.4955)  cardinality_error_4_unscaled: 4.0000 (4.8690)  time: 0.8198  data: 0.0254  max mem: 7230
# Epoch: [1]  [ 30/149]  eta: 0:01:41  lr: 0.000100  class_error: 66.67  loss: 14.0366 (14.1865)  loss_ce: 1.0322 (1.1237)  loss_bbox: 0.2123 (0.2233)  loss_giou: 0.9759 (0.9861)  loss_ce_0: 1.2178 (1.2808)  loss_bbox_0: 0.2360 (0.2326)  loss_giou_0: 0.9995 (0.9830)  loss_ce_1: 1.1100 (1.2052)  loss_bbox_1: 0.2172 (0.2177)  loss_giou_1: 0.9624 (0.9576)  loss_ce_2: 1.0555 (1.1632)  loss_bbox_2: 0.2191 (0.2195)  loss_giou_2: 0.9490 (0.9514)  loss_ce_3: 1.0565 (1.1418)  loss_bbox_3: 0.2161 (0.2218)  loss_giou_3: 0.9500 (0.9545)  loss_ce_4: 1.0475 (1.1291)  loss_bbox_4: 0.2206 (0.2219)  loss_giou_4: 0.9948 (0.9731)  loss_ce_unscaled: 1.0322 (1.1237)  class_error_unscaled: 66.6667 (67.6829)  loss_bbox_unscaled: 0.0425 (0.0447)  loss_giou_unscaled: 0.4879 (0.4931)  cardinality_error_unscaled: 4.0000 (4.9113)  loss_ce_0_unscaled: 1.2178 (1.2808)  loss_bbox_0_unscaled: 0.0472 (0.0465)  loss_giou_0_unscaled: 0.4997 (0.4915)  cardinality_error_0_unscaled: 3.7500 (4.4597)  loss_ce_1_unscaled: 1.1100 (1.2052)  loss_bbox_1_unscaled: 0.0434 (0.0435)  loss_giou_1_unscaled: 0.4812 (0.4788)  cardinality_error_1_unscaled: 3.7500 (4.2500)  loss_ce_2_unscaled: 1.0555 (1.1632)  loss_bbox_2_unscaled: 0.0438 (0.0439)  loss_giou_2_unscaled: 0.4745 (0.4757)  cardinality_error_2_unscaled: 4.0000 (4.6290)  loss_ce_3_unscaled: 1.0565 (1.1418)  loss_bbox_3_unscaled: 0.0432 (0.0444)  loss_giou_3_unscaled: 0.4750 (0.4772)  cardinality_error_3_unscaled: 4.7500 (5.0323)  loss_ce_4_unscaled: 1.0475 (1.1291)  loss_bbox_4_unscaled: 0.0441 (0.0444)  loss_giou_4_unscaled: 0.4974 (0.4866)  cardinality_error_4_unscaled: 4.2500 (4.9516)  time: 0.8118  data: 0.0248  max mem: 7230
# ...
# Epoch: [1]  [140/149]  eta: 0:00:07  lr: 0.000100  class_error: 83.33  loss: 12.7822 (13.8719)  loss_ce: 0.9018 (1.0993)  loss_bbox: 0.1886 (0.2164)  loss_giou: 0.8846 (0.9579)  loss_ce_0: 1.0937 (1.2554)  loss_bbox_0: 0.1857 (0.2200)  loss_giou_0: 0.9112 (0.9650)  loss_ce_1: 1.0362 (1.1885)  loss_bbox_1: 0.1850 (0.2097)  loss_giou_1: 0.9144 (0.9363)  loss_ce_2: 0.9836 (1.1431)  loss_bbox_2: 0.1837 (0.2115)  loss_giou_2: 0.8777 (0.9352)  loss_ce_3: 0.9326 (1.1188)  loss_bbox_3: 0.1855 (0.2113)  loss_giou_3: 0.8803 (0.9346)  loss_ce_4: 0.9450 (1.1054)  loss_bbox_4: 0.1913 (0.2151)  loss_giou_4: 0.8857 (0.9486)  loss_ce_unscaled: 0.9018 (1.0993)  class_error_unscaled: 61.9048 (63.9743)  loss_bbox_unscaled: 0.0377 (0.0433)  loss_giou_unscaled: 0.4423 (0.4789)  cardinality_error_unscaled: 4.5000 (6.5904)  loss_ce_0_unscaled: 1.0937 (1.2554)  loss_bbox_0_unscaled: 0.0371 (0.0440)  loss_giou_0_unscaled: 0.4556 (0.4825)  cardinality_error_0_unscaled: 3.7500 (5.3706)  loss_ce_1_unscaled: 1.0362 (1.1885)  loss_bbox_1_unscaled: 0.0370 (0.0419)  loss_giou_1_unscaled: 0.4572 (0.4681)  cardinality_error_1_unscaled: 3.2500 (5.2411)  loss_ce_2_unscaled: 0.9836 (1.1431)  loss_bbox_2_unscaled: 0.0367 (0.0423)  loss_giou_2_unscaled: 0.4388 (0.4676)  cardinality_error_2_unscaled: 3.5000 (5.9202)  loss_ce_3_unscaled: 0.9326 (1.1188)  loss_bbox_3_unscaled: 0.0371 (0.0423)  loss_giou_3_unscaled: 0.4402 (0.4673)  cardinality_error_3_unscaled: 4.0000 (6.4592)  loss_ce_4_unscaled: 0.9450 (1.1054)  loss_bbox_4_unscaled: 0.0383 (0.0430)  loss_giou_4_unscaled: 0.4429 (0.4743)  cardinality_error_4_unscaled: 4.2500 (6.5266)  time: 0.8073  data: 0.0277  max mem: 7230
# Epoch: [1]  [148/149]  eta: 0:00:00  lr: 0.000100  class_error: 53.85  loss: 13.1975 (13.9188)  loss_ce: 0.9012 (1.0977)  loss_bbox: 0.2165 (0.2199)  loss_giou: 0.9490 (0.9634)  loss_ce_0: 1.0873 (1.2527)  loss_bbox_0: 0.2288 (0.2238)  loss_giou_0: 0.9643 (0.9687)  loss_ce_1: 0.9704 (1.1865)  loss_bbox_1: 0.2115 (0.2139)  loss_giou_1: 0.9948 (0.9433)  loss_ce_2: 0.9381 (1.1410)  loss_bbox_2: 0.2321 (0.2156)  loss_giou_2: 1.0161 (0.9422)  loss_ce_3: 0.9165 (1.1164)  loss_bbox_3: 0.2116 (0.2152)  loss_giou_3: 0.9702 (0.9427)  loss_ce_4: 0.9184 (1.1038)  loss_bbox_4: 0.2133 (0.2186)  loss_giou_4: 0.9436 (0.9534)  loss_ce_unscaled: 0.9012 (1.0977)  class_error_unscaled: 56.8182 (63.9907)  loss_bbox_unscaled: 0.0433 (0.0440)  loss_giou_unscaled: 0.4745 (0.4817)  cardinality_error_unscaled: 6.7500 (6.6342)  loss_ce_0_unscaled: 1.0873 (1.2527)  loss_bbox_0_unscaled: 0.0458 (0.0448)  loss_giou_0_unscaled: 0.4822 (0.4844)  cardinality_error_0_unscaled: 4.0000 (5.3171)  loss_ce_1_unscaled: 0.9704 (1.1865)  loss_bbox_1_unscaled: 0.0423 (0.0428)  loss_giou_1_unscaled: 0.4974 (0.4717)  cardinality_error_1_unscaled: 4.0000 (5.1846)  loss_ce_2_unscaled: 0.9381 (1.1410)  loss_bbox_2_unscaled: 0.0464 (0.0431)  loss_giou_2_unscaled: 0.5080 (0.4711)  cardinality_error_2_unscaled: 5.0000 (5.8691)  loss_ce_3_unscaled: 0.9165 (1.1164)  loss_bbox_3_unscaled: 0.0423 (0.0430)  loss_giou_3_unscaled: 0.4851 (0.4714)  cardinality_error_3_unscaled: 5.0000 (6.4346)  loss_ce_4_unscaled: 0.9184 (1.1038)  loss_bbox_4_unscaled: 0.0427 (0.0437)  loss_giou_4_unscaled: 0.4718 (0.4767)  cardinality_error_4_unscaled: 5.7500 (6.5218)  time: 0.8205  data: 0.0271  max mem: 7230
# Epoch: [1] Total time: 0:02:06 (0.8474 s / it)
# Averaged stats: lr: 0.000100  class_error: 53.85  loss: 13.1975 (13.9188)  loss_ce: 0.9012 (1.0977)  loss_bbox: 0.2165 (0.2199)  loss_giou: 0.9490 (0.9634)  loss_ce_0: 1.0873 (1.2527)  loss_bbox_0: 0.2288 (0.2238)  loss_giou_0: 0.9643 (0.9687)  loss_ce_1: 0.9704 (1.1865)  loss_bbox_1: 0.2115 (0.2139)  loss_giou_1: 0.9948 (0.9433)  loss_ce_2: 0.9381 (1.1410)  loss_bbox_2: 0.2321 (0.2156)  loss_giou_2: 1.0161 (0.9422)  loss_ce_3: 0.9165 (1.1164)  loss_bbox_3: 0.2116 (0.2152)  loss_giou_3: 0.9702 (0.9427)  loss_ce_4: 0.9184 (1.1038)  loss_bbox_4: 0.2133 (0.2186)  loss_giou_4: 0.9436 (0.9534)  loss_ce_unscaled: 0.9012 (1.0977)  class_error_unscaled: 56.8182 (63.9907)  loss_bbox_unscaled: 0.0433 (0.0440)  loss_giou_unscaled: 0.4745 (0.4817)  cardinality_error_unscaled: 6.7500 (6.6342)  loss_ce_0_unscaled: 1.0873 (1.2527)  loss_bbox_0_unscaled: 0.0458 (0.0448)  loss_giou_0_unscaled: 0.4822 (0.4844)  cardinality_error_0_unscaled: 4.0000 (5.3171)  loss_ce_1_unscaled: 0.9704 (1.1865)  loss_bbox_1_unscaled: 0.0423 (0.0428)  loss_giou_1_unscaled: 0.4974 (0.4717)  cardinality_error_1_unscaled: 4.0000 (5.1846)  loss_ce_2_unscaled: 0.9381 (1.1410)  loss_bbox_2_unscaled: 0.0464 (0.0431)  loss_giou_2_unscaled: 0.5080 (0.4711)  cardinality_error_2_unscaled: 5.0000 (5.8691)  loss_ce_3_unscaled: 0.9165 (1.1164)  loss_bbox_3_unscaled: 0.0423 (0.0430)  loss_giou_3_unscaled: 0.4851 (0.4714)  cardinality_error_3_unscaled: 5.0000 (6.4346)  loss_ce_4_unscaled: 0.9184 (1.1038)  loss_bbox_4_unscaled: 0.0427 (0.0437)  loss_giou_4_unscaled: 0.4718 (0.4767)  cardinality_error_4_unscaled: 5.7500 (6.5218)
# Test:  [ 0/37]  eta: 0:01:05  class_error: 65.00  loss: 16.4651 (16.4651)  loss_ce: 1.2847 (1.2847)  loss_bbox: 0.3525 (0.3525)  loss_giou: 1.0595 (1.0595)  loss_ce_0: 1.3974 (1.3974)  loss_bbox_0: 0.3263 (0.3263)  loss_giou_0: 1.0739 (1.0739)  loss_ce_1: 1.4206 (1.4206)  loss_bbox_1: 0.3212 (0.3212)  loss_giou_1: 1.0560 (1.0560)  loss_ce_2: 1.2939 (1.2939)  loss_bbox_2: 0.3624 (0.3624)  loss_giou_2: 1.1060 (1.1060)  loss_ce_3: 1.3104 (1.3104)  loss_bbox_3: 0.3545 (0.3545)  loss_giou_3: 1.0519 (1.0519)  loss_ce_4: 1.2778 (1.2778)  loss_bbox_4: 0.3567 (0.3567)  loss_giou_4: 1.0595 (1.0595)  loss_ce_unscaled: 1.2847 (1.2847)  class_error_unscaled: 65.0000 (65.0000)  loss_bbox_unscaled: 0.0705 (0.0705)  loss_giou_unscaled: 0.5297 (0.5297)  cardinality_error_unscaled: 3.2500 (3.2500)  loss_ce_0_unscaled: 1.3974 (1.3974)  loss_bbox_0_unscaled: 0.0653 (0.0653)  loss_giou_0_unscaled: 0.5370 (0.5370)  cardinality_error_0_unscaled: 4.0000 (4.0000)  loss_ce_1_unscaled: 1.4206 (1.4206)  loss_bbox_1_unscaled: 0.0642 (0.0642)  loss_giou_1_unscaled: 0.5280 (0.5280)  cardinality_error_1_unscaled: 2.2500 (2.2500)  loss_ce_2_unscaled: 1.2939 (1.2939)  loss_bbox_2_unscaled: 0.0725 (0.0725)  loss_giou_2_unscaled: 0.5530 (0.5530)  cardinality_error_2_unscaled: 3.2500 (3.2500)  loss_ce_3_unscaled: 1.3104 (1.3104)  loss_bbox_3_unscaled: 0.0709 (0.0709)  loss_giou_3_unscaled: 0.5259 (0.5259)  cardinality_error_3_unscaled: 3.2500 (3.2500)  loss_ce_4_unscaled: 1.2778 (1.2778)  loss_bbox_4_unscaled: 0.0713 (0.0713)  loss_giou_4_unscaled: 0.5297 (0.5297)  cardinality_error_4_unscaled: 3.5000 (3.5000)  time: 1.7630  data: 1.1670  max mem: 7230
# Test:  [10/37]  eta: 0:00:15  class_error: 65.45  loss: 16.5151 (16.3414)  loss_ce: 1.3669 (1.3526)  loss_bbox: 0.1847 (0.1988)  loss_giou: 1.0595 (1.0961)  loss_ce_0: 1.5719 (1.5491)  loss_bbox_0: 0.1826 (0.1956)  loss_giou_0: 1.0739 (1.0800)  loss_ce_1: 1.4816 (1.4936)  loss_bbox_1: 0.1816 (0.1961)  loss_giou_1: 1.0560 (1.0971)  loss_ce_2: 1.4253 (1.4209)  loss_bbox_2: 0.1888 (0.2024)  loss_giou_2: 1.0958 (1.1255)  loss_ce_3: 1.3795 (1.3862)  loss_bbox_3: 0.1867 (0.2019)  loss_giou_3: 1.0519 (1.0969)  loss_ce_4: 1.3639 (1.3620)  loss_bbox_4: 0.1887 (0.2008)  loss_giou_4: 1.0595 (1.0860)  loss_ce_unscaled: 1.3669 (1.3526)  class_error_unscaled: 62.0000 (61.4445)  loss_bbox_unscaled: 0.0369 (0.0398)  loss_giou_unscaled: 0.5297 (0.5480)  cardinality_error_unscaled: 7.7500 (8.5909)  loss_ce_0_unscaled: 1.5719 (1.5491)  loss_bbox_0_unscaled: 0.0365 (0.0391)  loss_giou_0_unscaled: 0.5370 (0.5400)  cardinality_error_0_unscaled: 6.5000 (6.9773)  loss_ce_1_unscaled: 1.4816 (1.4936)  loss_bbox_1_unscaled: 0.0363 (0.0392)  loss_giou_1_unscaled: 0.5280 (0.5485)  cardinality_error_1_unscaled: 6.2500 (6.3409)  loss_ce_2_unscaled: 1.4253 (1.4209)  loss_bbox_2_unscaled: 0.0378 (0.0405)  loss_giou_2_unscaled: 0.5479 (0.5627)  cardinality_error_2_unscaled: 6.7500 (6.8182)  loss_ce_3_unscaled: 1.3795 (1.3862)  loss_bbox_3_unscaled: 0.0373 (0.0404)  loss_giou_3_unscaled: 0.5259 (0.5485)  cardinality_error_3_unscaled: 6.5000 (7.4318)  loss_ce_4_unscaled: 1.3639 (1.3620)  loss_bbox_4_unscaled: 0.0377 (0.0402)  loss_giou_4_unscaled: 0.5297 (0.5430)  cardinality_error_4_unscaled: 6.0000 (7.9545)  time: 0.5865  data: 0.1321  max mem: 7230
# Test:  [20/37]  eta: 0:00:09  class_error: 51.92  loss: 15.0237 (15.0471)  loss_ce: 1.2302 (1.2382)  loss_bbox: 0.1744 (0.1858)  loss_giou: 1.0076 (1.0170)  loss_ce_0: 1.4184 (1.4252)  loss_bbox_0: 0.1733 (0.1796)  loss_giou_0: 1.0105 (0.9979)  loss_ce_1: 1.3488 (1.3655)  loss_bbox_1: 0.1727 (0.1820)  loss_giou_1: 1.0120 (1.0168)  loss_ce_2: 1.2939 (1.3008)  loss_bbox_2: 0.1804 (0.1869)  loss_giou_2: 1.0499 (1.0401)  loss_ce_3: 1.2596 (1.2696)  loss_bbox_3: 0.1806 (0.1873)  loss_giou_3: 1.0244 (1.0183)  loss_ce_4: 1.2331 (1.2458)  loss_bbox_4: 0.1724 (0.1859)  loss_giou_4: 1.0091 (1.0042)  loss_ce_unscaled: 1.2302 (1.2382)  class_error_unscaled: 51.9231 (53.6246)  loss_bbox_unscaled: 0.0349 (0.0372)  loss_giou_unscaled: 0.5038 (0.5085)  cardinality_error_unscaled: 9.2500 (10.1071)  loss_ce_0_unscaled: 1.4184 (1.4252)  loss_bbox_0_unscaled: 0.0347 (0.0359)  loss_giou_0_unscaled: 0.5053 (0.4990)  cardinality_error_0_unscaled: 6.5000 (6.7024)  loss_ce_1_unscaled: 1.3488 (1.3655)  loss_bbox_1_unscaled: 0.0345 (0.0364)  loss_giou_1_unscaled: 0.5060 (0.5084)  cardinality_error_1_unscaled: 5.5000 (6.3929)  loss_ce_2_unscaled: 1.2939 (1.3008)  loss_bbox_2_unscaled: 0.0361 (0.0374)  loss_giou_2_unscaled: 0.5250 (0.5200)  cardinality_error_2_unscaled: 6.7500 (7.6071)  loss_ce_3_unscaled: 1.2596 (1.2696)  loss_bbox_3_unscaled: 0.0361 (0.0375)  loss_giou_3_unscaled: 0.5122 (0.5092)  cardinality_error_3_unscaled: 7.2500 (8.5595)  loss_ce_4_unscaled: 1.2331 (1.2458)  loss_bbox_4_unscaled: 0.0345 (0.0372)  loss_giou_4_unscaled: 0.5046 (0.5021)  cardinality_error_4_unscaled: 7.7500 (9.1310)  time: 0.4700  data: 0.0274  max mem: 7230
# Test:  [30/37]  eta: 0:00:03  class_error: 50.00  loss: 13.6590 (14.6107)  loss_ce: 1.1228 (1.2059)  loss_bbox: 0.1744 (0.1865)  loss_giou: 0.9154 (0.9866)  loss_ce_0: 1.2941 (1.3689)  loss_bbox_0: 0.1733 (0.1827)  loss_giou_0: 0.9135 (0.9738)  loss_ce_1: 1.2345 (1.3108)  loss_bbox_1: 0.1721 (0.1835)  loss_giou_1: 0.9007 (0.9866)  loss_ce_2: 1.1783 (1.2583)  loss_bbox_2: 0.1782 (0.1875)  loss_giou_2: 0.9401 (1.0082)  loss_ce_3: 1.1540 (1.2288)  loss_bbox_3: 0.1751 (0.1875)  loss_giou_3: 0.9331 (0.9867)  loss_ce_4: 1.1249 (1.2122)  loss_bbox_4: 0.1707 (0.1864)  loss_giou_4: 0.9076 (0.9700)  loss_ce_unscaled: 1.1228 (1.2059)  class_error_unscaled: 50.9434 (55.0275)  loss_bbox_unscaled: 0.0349 (0.0373)  loss_giou_unscaled: 0.4577 (0.4933)  cardinality_error_unscaled: 8.2500 (9.2177)  loss_ce_0_unscaled: 1.2941 (1.3689)  loss_bbox_0_unscaled: 0.0347 (0.0365)  loss_giou_0_unscaled: 0.4568 (0.4869)  cardinality_error_0_unscaled: 4.0000 (5.7984)  loss_ce_1_unscaled: 1.2345 (1.3108)  loss_bbox_1_unscaled: 0.0344 (0.0367)  loss_giou_1_unscaled: 0.4503 (0.4933)  cardinality_error_1_unscaled: 4.7500 (5.8548)  loss_ce_2_unscaled: 1.1783 (1.2583)  loss_bbox_2_unscaled: 0.0356 (0.0375)  loss_giou_2_unscaled: 0.4700 (0.5041)  cardinality_error_2_unscaled: 6.5000 (7.0645)  loss_ce_3_unscaled: 1.1540 (1.2288)  loss_bbox_3_unscaled: 0.0350 (0.0375)  loss_giou_3_unscaled: 0.4665 (0.4934)  cardinality_error_3_unscaled: 7.0000 (7.7742)  loss_ce_4_unscaled: 1.1249 (1.2122)  loss_bbox_4_unscaled: 0.0341 (0.0373)  loss_giou_4_unscaled: 0.4538 (0.4850)  cardinality_error_4_unscaled: 7.5000 (8.2903)  time: 0.5240  data: 0.0393  max mem: 7230
# Test:  [36/37]  eta: 0:00:00  class_error: 100.00  loss: 13.3448 (14.0499)  loss_ce: 1.0685 (1.1183)  loss_bbox: 0.1818 (0.2028)  loss_giou: 0.8925 (0.9737)  loss_ce_0: 1.1526 (1.2602)  loss_bbox_0: 0.1876 (0.2024)  loss_giou_0: 0.9135 (0.9649)  loss_ce_1: 1.0993 (1.2070)  loss_bbox_1: 0.1881 (0.2023)  loss_giou_1: 0.8929 (0.9742)  loss_ce_2: 1.1170 (1.1638)  loss_bbox_2: 0.1910 (0.2030)  loss_giou_2: 0.9055 (0.9941)  loss_ce_3: 1.0960 (1.1354)  loss_bbox_3: 0.1881 (0.2043)  loss_giou_3: 0.8663 (0.9660)  loss_ce_4: 1.0831 (1.1204)  loss_bbox_4: 0.1767 (0.2026)  loss_giou_4: 0.8980 (0.9543)  loss_ce_unscaled: 1.0685 (1.1183)  class_error_unscaled: 51.9231 (56.2516)  loss_bbox_unscaled: 0.0364 (0.0406)  loss_giou_unscaled: 0.4462 (0.4868)  cardinality_error_unscaled: 7.0000 (7.9797)  loss_ce_0_unscaled: 1.1526 (1.2602)  loss_bbox_0_unscaled: 0.0375 (0.0405)  loss_giou_0_unscaled: 0.4568 (0.4824)  cardinality_error_0_unscaled: 3.2500 (5.0811)  loss_ce_1_unscaled: 1.0993 (1.2070)  loss_bbox_1_unscaled: 0.0376 (0.0405)  loss_giou_1_unscaled: 0.4464 (0.4871)  cardinality_error_1_unscaled: 3.7500 (5.1419)  loss_ce_2_unscaled: 1.1170 (1.1638)  loss_bbox_2_unscaled: 0.0382 (0.0406)  loss_giou_2_unscaled: 0.4527 (0.4970)  cardinality_error_2_unscaled: 4.2500 (6.1486)  loss_ce_3_unscaled: 1.0960 (1.1354)  loss_bbox_3_unscaled: 0.0376 (0.0409)  loss_giou_3_unscaled: 0.4331 (0.4830)  cardinality_error_3_unscaled: 4.5000 (6.7365)  loss_ce_4_unscaled: 1.0831 (1.1204)  loss_bbox_4_unscaled: 0.0353 (0.0405)  loss_giou_4_unscaled: 0.4490 (0.4772)  cardinality_error_4_unscaled: 5.5000 (7.1824)  time: 0.5131  data: 0.0379  max mem: 7230
# Test: Total time: 0:00:19 (0.5289 s / it)
# Averaged stats: class_error: 100.00  loss: 13.3448 (14.0499)  loss_ce: 1.0685 (1.1183)  loss_bbox: 0.1818 (0.2028)  loss_giou: 0.8925 (0.9737)  loss_ce_0: 1.1526 (1.2602)  loss_bbox_0: 0.1876 (0.2024)  loss_giou_0: 0.9135 (0.9649)  loss_ce_1: 1.0993 (1.2070)  loss_bbox_1: 0.1881 (0.2023)  loss_giou_1: 0.8929 (0.9742)  loss_ce_2: 1.1170 (1.1638)  loss_bbox_2: 0.1910 (0.2030)  loss_giou_2: 0.9055 (0.9941)  loss_ce_3: 1.0960 (1.1354)  loss_bbox_3: 0.1881 (0.2043)  loss_giou_3: 0.8663 (0.9660)  loss_ce_4: 1.0831 (1.1204)  loss_bbox_4: 0.1767 (0.2026)  loss_giou_4: 0.8980 (0.9543)  loss_ce_unscaled: 1.0685 (1.1183)  class_error_unscaled: 51.9231 (56.2516)  loss_bbox_unscaled: 0.0364 (0.0406)  loss_giou_unscaled: 0.4462 (0.4868)  cardinality_error_unscaled: 7.0000 (7.9797)  loss_ce_0_unscaled: 1.1526 (1.2602)  loss_bbox_0_unscaled: 0.0375 (0.0405)  loss_giou_0_unscaled: 0.4568 (0.4824)  cardinality_error_0_unscaled: 3.2500 (5.0811)  loss_ce_1_unscaled: 1.0993 (1.2070)  loss_bbox_1_unscaled: 0.0376 (0.0405)  loss_giou_1_unscaled: 0.4464 (0.4871)  cardinality_error_1_unscaled: 3.7500 (5.1419)  loss_ce_2_unscaled: 1.1170 (1.1638)  loss_bbox_2_unscaled: 0.0382 (0.0406)  loss_giou_2_unscaled: 0.4527 (0.4970)  cardinality_error_2_unscaled: 4.2500 (6.1486)  loss_ce_3_unscaled: 1.0960 (1.1354)  loss_bbox_3_unscaled: 0.0376 (0.0409)  loss_giou_3_unscaled: 0.4331 (0.4830)  cardinality_error_3_unscaled: 4.5000 (6.7365)  loss_ce_4_unscaled: 1.0831 (1.1204)  loss_bbox_4_unscaled: 0.0353 (0.0405)  loss_giou_4_unscaled: 0.4490 (0.4772)  cardinality_error_4_unscaled: 5.5000 (7.1824)
# Accumulating evaluation results...
# DONE (t=0.20s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.124
# Training time 0:04:54

# %% [markdown]
# # Testing fine-tuning/training result
# Adopted from here https://colab.research.google.com/github/facebookresearch/detr/blob/colab/notebooks/detr_attention.ipynb#scrollTo=8yls9cpVYTEg

# %%
from argparse import Namespace

torch.serialization.add_safe_globals([Namespace])

model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet50',
                       pretrained=False,
                       num_classes=num_classes,
                           )

checkpoint = torch.load('outputs/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval();
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from PIL import Image
image = Image.open("/content/train2017/n003-2018-01-03-12-03-23+0800__CAM_BACK_RIGHT__1514952966577338.jpg")

# %%
import torchvision.transforms as T

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
# mean-std normalize the input image (batch-size: 1)
img = transform(image).unsqueeze(0)

# propagate through the model
outputs = model(img)

# keep only predictions with 0.7+ confidence
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.5

# convert boxes from [0; 1] to image scales
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], image.size)

# %%
plot_results(image, probas[keep], bboxes_scaled)
